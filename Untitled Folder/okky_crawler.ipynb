# %%
import requests
from bs4 import BeautifulSoup
import chardet
import pickle
from tqdm import tqdm
import numpy as np
import time

# %%
seed="https://okky.kr"
params = {
    "max":"100",
    "sort":"id",
    "order":"desc"
}
headers = {
    "User-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36",
    "Accept-Encoding":None #인코딩 문제 해결 위해
}

resp = requests.get(seed+"/articles/tech-qna",params=params, headers=headers)

# %%
chardet.detect(resp.content)
# Out:
# {'confidence': 0.99, 'encoding': 'utf-8', 'language': ''}

# %%
soup = BeautifulSoup(resp.content,'lxml')

# %%
h5 = soup.select('h5 > a')
h5[:5]
# Out:
# [<a href="/article/423650">
#
#                  OKKY Q&amp;A 운영 안내 - 질문 전 꼭 읽어보세요!
#              </a>, <a href="/article/508699">
#
#                  리스너 호출 오류
#              </a>, <a href="/article/508698">
#
#                  씨언어 잘 아시는분들.. 시간 나시면 코드짜기좀 봐주실수 있으신가요?
#              </a>, <a href="/article/508693">
#
#                  jsonObject-&gt; Ajax 호출 질문입니다. 중복검사
#              </a>, <a href="/article/508691">
#
#                  Angular와 React 궁금한것이 있습니다.
#              </a>]

# %%
links = [el['href'] for el in h5]
links[1:10]
# Out:
# ['/article/508699',
#  '/article/508698',
#  '/article/508693',
#  '/article/508691',
#  '/article/508690',
#  '/article/508688',
#  '/article/508680',
#  '/article/508650',
#  '/article/508643']

# %% [markdown]
# 함수로 만들어보자

# %%
def get_links(resp)->list:
    try:
        soup = BeautifulSoup(resp.content,'lxml')
        h5 = soup.select('h5 > a')
        links = [el['href'] for el in h5[1:]]
        
    except Exception as e:
        print("Exception occurs in get_links",resp.url,e)
    return links

# %%
def get_QA(links:list):
    def get_qid(soup,que):
        try:
            que.append(soup.find("span",{"class":"list-group-item-text article-id"}).text)
        except Exception as e:
            que.append(np.nan)
    def get_uid(soup,que):
        try:
            tmp = soup.find("span",{"class":"nickname"})
            if tmp==None:
                tmp = soup.find("a",{"class":"nickname"})
            que.append(tmp.text)
        except Exception as e:
            que.append(np.nan)        
    def get_tstamp(soup,que):
        try:
            que.append(soup.find("span",{"class":"timeago"}).text)
        except Exception as e:
            que.append(np.nan)  
    def get_tags(soup,que):
        try:
            que.append(tuple([tag.text for tag in soup.find_all("a",{"class":"list-group-item-text item-tag label label-gray"})]))
        except Exception as e:
            que.append(tuple())
    def get_view(soup,que):
        try:
            que.append(soup.find("div",{"class":"content-identity-count"}).text)
        except Exception as e:
            que.append(np.nan)
    def get_vote(soup,que):
        try:
            que.append(soup.find("div",{"class":"content-eval-count"}).text)
        except Exception as e:
            que.append(np.nan)
    def get_title(soup,que):
        try:
            que.append(soup.find("h2",{"class":"panel-title"}).text.strip())
        except Exception as e:
            que.append(np.nan)
    def get_content(soup,que):
        try:
            content = tuple([p.text.strip() for p in soup.select("#content-body > article > p")]) # p로 구분된 본문
            if content == tuple():
                content = soup.find("article",{"class":"content-text"}).text.strip()
            que.append(content)      
        except Exception as e:
            que.append(tuple())
    def get_code(soup,que):
        try:
            que.append(tuple([pre.text.strip() for pre in soup.select("#content-body > article > pre")]))
        except Exception as e:
            que.append(tuple())
    def get_uid_a(li):
        try:
            tmp = li.find("a",{"class":"nickname"})
            if tmp ==None:
                tmp = li.find("span",{"class":"nickname"})
            an.append(tmp.text)
        except Exception as e:
            an.append(np.nan)
    def get_tstamp_a(li):
        try:
            an.append(li.find("span",{"class":"timeago"}).text)
        except Exception as e:
            an.append(np.nan) 
    def get_vote_a(li):
        try:
            an.append(li.find("div",{"class":"content-eval-count"}).text)
        except Exception as e:
            an.append(np.nan)
    def get_comment(li):
        try:
            an.append(li.find("article",{"class":"list-group-item-text note-text"}).text.strip())
        except Exception as e:
            an.append(np.nan)
    
    
    for link in links:
        try:
            url = seed + link
            resp = requests.get(url, headers=headers,timeout=3)
            soup = BeautifulSoup(resp.content,'lxml')
            
            que = []
            
            get_qid(soup,que)
            get_uid(soup,que)
            get_tstamp(soup,que)
            get_tags(soup,que)
            get_view(soup,que)
            get_vote(soup,que)
            get_title(soup,que)   
            get_content(soup,que)    
            get_code(soup,que)   
            
            ques[que[0]] = tuple(que[1:])
            ans[que[0]] = {}
            
            lst_group = soup.find("ul",{"class":"list-group"})
            if lst_group==None:
                continue
            lis = lst_group.find_all("li",{"class","list-group-item note-item clearfix"})
            if lis == []:
                continue
            for i,li in enumerate(lis):
                an = []

                get_uid_a(li)
                get_tstamp_a(li)
                get_vote_a(li)
                get_comment(li) 

                ans[que[0]][str(que[0])+'_'+str(i)] = tuple(an) # 댓글의 id를 str(que[0])+'_'+str(i)로 지정하고 이를 키로 설정
   
        except Exception as e:
            print("Exception occurs in get_QA",link,e)
            continue

# %%
if __name__=="__main__":
    seed="https://okky.kr"
    params = {
        "max":"100",
        "sort":"id",
        "order":"asc",
        "offset":"0"
    }
    headers = {
        "User-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36",
    #     "Accept-Encoding":None #인코딩 문제 해결 위해
    }
    
    ques = {} # ques = {que_id:(user_id, time_stamp, (tags), views, vote_count, title, content, code)}
    ans = {} # ans = {que_id: {an_id:(user_id, time_stamp, vote_count, content)} }
    
    for offset in tqdm(range(0,100,100)):
        try:
            params['offset'] = str(offset)
            resp = requests.get(seed+"/articles/tech-qna",params=params, headers=headers)
            
            links = get_links(resp)
            
            get_QA(links)
            
            
        except Exception as e:
            print("Exception occurs in main",e)
            continue
        
        finally:
            with open('questions.dic','wb') as fp:
                pickle.dump(ques,fp)
            with open('answers.dic','wb') as fp:
                pickle.dump(ans,fp)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:13<00:00, 13.13s/it]

# %%
with open('questions.dic','rb') as fp:
    questions = pickle.load(fp)
questions
# Out:
# {'#1': ('kenu',
#   '2001-07-25 01:43:23',
#   ('db', ' 데이터베이스'),
#   ' 1',
#   '1',
#   '오라클 질문 답변 게시판입니다.',
#   '오라클 실무경험이 많으신 분(laalaal)께서 게시판 관리해 주실 것입니다.KOUG 에서 활약하신 실력!짱!인 분입니다.질문 올리실 때에 가능하면 oracle 버전과 환경을 알려주시면 답변이 빨리될 수 있습니다.QnA 게시판의 의의는 질문을 올려서 얼마나 빨리 정확하게 답변을 받느냐도 중요하지만 이전에 같은 문제로 고생한 사람들의 경험담을 보면서 자신의 문제를 빨리 파악하고 해결방안을 검색할 수 있는 database 구축/검색활용이라는 쪽에 있습니다.같이 공유합시다.',
#   ()),
#  '#10': ('질문맨',
#   '2001-07-26 07:11:10',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '컴파일을 하니까 에러가 나네여..',
#   '님이 주신 소스로 컴파일을 하니까ArticleList.java에서컴파일을 하니까에러가 남니다ArticleList.java:94: cannot resolve symbolsymbol  : class Articlelocation: class ok.ArticleList\t\t\t\tArticle article = new Article(seq, ref, step, lev, bwriter, subject, password, email, read, fileName, maskName, fileSize, download, when, ip);ArticleList.java:94: cannot resolve symbolsymbol  : class Articlelocation: class ok.ArticleList\t\t\t\tArticle article = new Article(seq, ref, step, lev, bwriter, subject, password, email, read, fileName, maskName, fileSize, download, when, ip);',
#   ()),
#  '#103': ('초보',
#   '2001-07-30 09:46:23',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '한글 처리문제...',
#   '자바의 유니코드 문제로 한글과 영문이 동일하게 1자로 인식을 하는데 웹에서 보여질때 자리수 문제로 영문,숫자는 1 한글 2자로 인식하게 하고싶은데요.방법을 좀...',
#   ()),
#  '#104': ('나',
#   '2001-07-30 09:56:42',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '[Q]Full thread dump? && java.lang.OutOfMemoryError',
#   '아래와 같은 에러가 발생하고 있습니다.tomcat3.1 + apache + mysql + 솔라리스를 사용중입니다.자꾸 에러가 나네요.부탁드립니다.java.lang.OutOfMemoryErrorat org.apache.tomcat.service.SimpleTcpEndpoint.processSocket(Compiled Code)at org.apache.tomcat.service.SimpleTcpEndpoint.acceptConnections(Compiled Code)at org.apache.tomcat.service.TcpListenerThread.run(Compiled Code)at java.lang.Thread.run(Compiled Code)Endpoint ServerSocket[addr=0.0.0.0/0.0.0.0,port=0,localport=8007] shutdown due to exception: java.lang.OutOfMemoryErrorSIGSEGV 11* segmentation violationsi_signo [11]: SIGSEGV 11* segmentation violationsi_errno [0]: Error 0si_code [1]: SEGV_MAPERR [addr: 0x8bc18928]stackbase=DDF4AD9C, stackpointer=DDF4A96CFull thread dump:',
#   ()),
#  '#107': ('에어울프',
#   '2001-07-30 11:11:45',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '오늘 글의 총 갯수 구하기(질문)',
#   '안냐세요..계속 님의 도움을 받고 있는 허접입니다.게시판을 바꾸셨네요..한가지 문의할 것은 오늘 입력한 글의 총 갯수를 구하는 방법인데요..날짜가 db에 저장될때 datetime형식으로 저장됩니다.이걸 쿼리해서 오늘 날짜와 비교를 해서 오늘 입력한 글의 갯수를 구하고 싶습니다.그런데 db에 입력된 날짜는 보기에는 2001-07-30 오전.... 이런 형식으로 보여지지만 실제는 그게 아닌거 같습니다.Date today = new Date();SimpleDateFormat formatter = new SimpleDateFormat("yyyy-MM- dd");int total = 0;query = "select count(*) from bbs where todate like \'%(formatter.format(today))%\'";    pstmt = dbCon.prepareStatement(query);    rs = pstmt.executeQuery();    if(rs.next())\t    total = rs.getInt(1);    rs.close();이런식으로 하면 도저히 원하는 결과를 찾을 수 없습니다.오늘 글의 갯수를 구하는 좋은 방법이 있으면 가르쳐 주세요..수고하세요.....',
#   ()),
#  '#108': ('박선형',
#   '2001-07-30 11:13:42',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'JSP를 돌리는데 필요한 컴퓨터의 최소 사양을 알고 싶습니다.',
#   '안녕하세요?JSP 최소사양에 대해 알고 싶습니다.JSP 돌리는데 최소사양이 나와있는 JSP문서나 사이트도 알려주시면 감사하겠습니다.',
#   ()),
#  '#109': ('스노',
#   '2001-07-30 11:53:14',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'Bean을 사용하려하면 에러가...',
#   'java파일을 만들어 컴파일해놓은 후 Bean을 사용하려 하면 에러가 나네요. ㅡㅡ;에러 내용은 아래와 같고요. Bean만 사용하면 에러나는데.. 답답하네요 ㅡㅡ; 누구 자세하게 설명좀 해주시길..Error: 500Location: /jsp/counter.jspInternal Servlet Error:org.apache.jasper.compiler.ParseException: E:\\web\\root\\jsp\\counter.jsp(0,4) Invalid directive\tat org.apache.jasper.compiler.Parser$Directive.accept(Parser.java:186)\tat org.apache.jasper.compiler.Parser.parse(Parser.java:1077)\tat org.apache.jasper.compiler.Parser.parse(Parser.java:1042)\tat org.apache.jasper.compiler.Parser.parse(Parser.java:1038)\tat org.apache.jasper.compiler.Compiler.compile(Compiler.java:209)\tat org.apache.jasper.servlet.JspServlet.doLoadJSP(JspServlet.java:612)\tat org.apache.jasper.servlet.JasperLoader12.loadJSP(JasperLoader12.java:146)\tat org.apache.jasper.servlet.JspServlet.loadJSP(JspServlet.java:542)\tat org.apache.jasper.servlet.JspServlet$JspServletWrapper.loadIfNecessary(JspServlet.java:258)\tat org.apache.jasper.servlet.JspServlet$JspServletWrapper.service(JspServlet.java:268)\tat org.apache.jasper.servlet.JspServlet.serviceJspFile(JspServlet.java:429)\tat org.apache.jasper.servlet.JspServlet.service(JspServlet.java:500)\tat javax.servlet.http.HttpServlet.service(HttpServlet.java:853)\tat org.apache.tomcat.core.ServletWrapper.doService(ServletWrapper.java:405)\tat org.apache.tomcat.core.Handler.service(Handler.java:287)\tat org.apache.tomcat.core.ServletWrapper.service(ServletWrapper.java:372)\tat org.apache.tomcat.core.ContextManager.internalService(ContextManager.java:812)\tat org.apache.tomcat.core.ContextManager.service(ContextManager.java:758)\tat org.apache.tomcat.service.http.HttpConnectionHandler.processConnection(HttpConnectionHandler.java:213)\tat org.apache.tomcat.service.TcpWorkerThread.runIt(PoolTcpEndpoint.java:416)\tat org.apache.tomcat.util.ThreadPool$ControlRunnable.run(ThreadPool.java:501)\tat java.lang.Thread.run(Thread.java:484)',
#   ()),
#  '#113': ('강희도',
#   '2001-07-30 12:42:55',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '톰캣에서 sendRedierct()....',
#   '톰켓에서는 sendredirect가 문제가 있다고 해서 다음과 같이 해주었습니다.public String sendRedirect(String strURL){String strMeta = "<meta http-equiv=\'Refresh\' content=\'0; URL="+strURL+"\'>";return strMeta;}그런데 문제는 write.jsp에서out.println(boardutil.sendRedirect("list.jsp"));이렇게 해주는데요..글을 쓴후 write.jsp를 한번 뿌려준후 list.jsp로 넘어가드라구요.회원인증을 통하지 않은 회원은 그 페이지에 접근을 못하게 하려고 하는 건데... 한번 그 페이지를 보여준후 이동을 합니다.다른 방법이 있을까요?',
#   ()),
#  '#117': ('kang',
#   '2001-07-30 13:22:05',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'mysql에러 문제',
#   'win2000에서 mysql을 설치하고 mysql-nt --install을 실행한다음 서비스에서 mysql을 시작했는데 에러1064: 프로세스가 예기치않게 종료되었습니다라고 계속 듭니다어떻게 해야 하나요...',
#   ()),
#  '#119': ('신경훈',
#   '2001-07-30 14:03:05',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '초보적인문제인데여,tomcat&apache 설정에 관한',
#   '저는 영진출판사의 About JSP책을 보고 공부하고 있는데요.그곳에 보면 JSP파일은 jakart-tomcat\\webapps\\ROOT 밑에다가 넣으라고 하는데, 그것을 그냥 웹서비스하는 디렉토리에서실행하게는 못하나여.저는 웹서비스는 D:\\WebService라는 폴더에서 서비스를하거든요..그런데 그밑에다가 jsp파일을 놓으니까 찾지를 못하고위의 tomcat의 폴더에다 넣어야지 되더라구요.이것을 그냥 D:\\WebService에서 다 실행되게 하려면어떻게 설정을 해야 하죠.또, 이렇게 한군데다가 쓰면 문제점이라두 있나요?제 환경은 Windows2000Server에 Apache1.3.20, tomcat 최신판을 쓰는데여....가르쳐주시와요!!',
#   ()),
#  '#120': ('박선형',
#   '2001-07-30 14:03:27',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '질문입니다.',
#   '안녕하세요?제 전 질문에 답변해주셔서 고맙습니다.지금 저희 회사에서 추후에 JSP 회원가입및 게시판을 서비스하려고 하는데요,톰켓, 아파치를 사용하는데 있어 무료로 사용할 수 있는지요?무료인지를 확인하려면 어떤 사이트를 검색해보면 되는지요?감사합니다.',
#   ()),
#  '#125': ('오형석',
#   '2001-07-30 14:20:42',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'mysql실행에 관한 에러 인데요.... 도와주세요..--;;',
#   '안녕하세요. jsp를 공부하고 있는 학생인데요..이것땜시 막혀서 몇일을 고생하고 있습니다... 여기에 있는 강좌대로 자료입력과 자료조회등은 되는데 책에있는 거 따라 할려고 하니까 에러가 나네요..내용은 다음과 같습니다. 참고로 제가 가지고 있는 책은 정보게이트의 jump to jsp입니다..[dbConn.jsp]----------------------------------------------------------<%@ page language="java" import="java.sql.*" %><%  Class.forName("org.gjt.mm.mysql.Driver");  Connection myConn = DriverManager.getConnection("jdbc:mysql://localhost/test?user=root&password=1111");  Statement stmt = myConn.createStatement();%>----------------------------------------------------------[register_ok.jsp]<%@ include file="dbConn.jsp" %><%@ page contentType = "text/html; charset=euc-kr" %><%  String userid = new String (request.getParameter("userid").getBytes("KSC5601"),"8859_1");  String userpwd = new String (request.getParameter("userpwd").getBytes("KSC5601"),"8859_1");  String name = new String (request.getParameter("name").getBytes("KSC5601"),"8859_1");  String email = new String (request.getParameter("email").getBytes("KSC5601"),"8859_1");  String address = new String (request.getParameter("address").getBytes("KSC5601"),"8859_1"); ResultSet rs = stmt.executeQuery("select * from membership where userid =\'"+userid+"\'");  if (rs.next())     {%><script language="javascript">  alert("이미 존재하는 아이디입니다");  history.back();</script><%     }  else     {      String sql = "insert into membership (userid,userpwd,name,email,address)";      sql =  sql + "values (\'"+userid+"\',\'"+userpwd+"\',\'"+name+"\',\'"+email+"\',\'"+address+"\')";      stmt.executeUpdate(sql);     }%>---------------------------------------------------[register.jsp]<html><head><title>회원가입</title></head><body bgcolor="#FFFFCC"><center>회원가입</center><hr width="80%"><form action="register_ok.jsp" method="post"><table border="1" align="center">   <tr>     <td>아이디</td>     <td><input type="text" name="userid"></td>   </tr>   <tr>     <td>패스워드</td>     <td><input type="password" name="userpwd"></td>   </tr>   <tr>     <td>이름</td>     <td><input type="text" name="name"></td>   </tr>   <tr>     <td>이메일</td>     <td><input type="text" name="email"></td>   </tr>   <tr>     <td>주소</td>     <td><input type="text" name="address" size=30></td>   </tr>   <tr>     <td>&nbsp;</td>     <td><input type="submit"></td>   </tr></table></form><hr width="80%"><table border="0" align="center">   <tr>     <td><a href="login.jsp">로그인</a></td>     <td>&nbsp;</td>     <td>회원가입</td>   </tr></table></body></html>--------------------------------------------------------- 소스는 위의 내용과 같구요. 책에는 그대로 하면 된다구 했는데브라우저에서 register.jsp실행시켜서 쿼리전송하면 계속 에러가나네요. 여기에 있는 강좌대로 하면 디비에 잘 저장되는 걸보닌 패스 지정문제는 아닌 것같고, 여러 사이트 돌아다녀봐도 별로 정확한 해답을 얻지 못해서 이렇게 도움을 청합니다..',
#   ()),
#  '#126': ('이정석',
#   '2001-07-30 15:36:27',
#   ('db', ' 데이터베이스'),
#   ' 0',
#   '0',
#   '질문이요...',
#   'win98에 오라클8i(클라이언트) 를 설치했는데, jsp 연동 방법을모르겠습니다. 아파치+톰켓으로 웹서버를 구성했구요...처음 사용해보는 거라 어렵네요. 답변 부탁합니다.',
#   ()),
#  '#128': ('초보',
#   '2001-07-30 15:42:49',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '방명록작성에러(javax.servlet.ServletException)',
#   '방명록에 글을 입력하고 나서 입력한 글을 데이타베이스에 입력시 에러입니다..nullexception 에러라고 하는데 어디서 그런건지 알수가없네요..에러코드는Error: 500Location: /guestbook/write_ok.jspInternal Servlet Error:javax.servlet.ServletException\tat org.apache.jasper.runtime.PageContextImpl.handlePageException(PageContextImpl.java:459)\tat guestbook._0002fguestbook_0002fwrite_0005fok_0002ejspwrite_0005fok_jsp_6._jspService(_0002fguestbook_0002fwrite_0005fok_0002ejspwrite_0005fok_jsp_6.java:156)\tat org.apache.jasper.runtime.HttpJspBase.service(HttpJspBase.java:119)\tat javax.servlet.http.HttpServlet.service(HttpServlet.java:853)\tat org.apache.jasper.servlet.JspServlet$JspServletWrapper.service(JspServlet.java:177)\tat org.apache.jasper.servlet.JspServlet.serviceJspFile(JspServlet.java:318)\tat org.apache.jasper.servlet.JspServlet.service(JspServlet.java:391)\tat javax.servlet.http.HttpServlet.service(HttpServlet.java:853)\tat org.apache.tomcat.core.ServletWrapper.doService(ServletWrapper.java:404)\tat org.apache.tomcat.core.Handler.service(Handler.java:286)\tat org.apache.tomcat.core.ServletWrapper.service(ServletWrapper.java:372)\tat org.apache.tomcat.core.ContextManager.internalService(ContextManager.java:797)\tat org.apache.tomcat.core.ContextManager.service(ContextManager.java:743)\tat org.apache.tomcat.service.http.HttpConnectionHandler.processConnection(HttpConnectionHandler.java:210)\tat org.apache.tomcat.service.TcpWorkerThread.runIt(PoolTcpEndpoint.java:416)\tat org.apache.tomcat.util.ThreadPool$ControlRunnable.run(ThreadPool.java:498)\tat java.lang.Thread.run(Thread.java:484)Root cause:java.lang.NullPointerException\tat guestbook._0002fguestbook_0002fwrite_0005fok_0002ejspwrite_0005fok_jsp_6._jspService(_0002fguestbook_0002fwrite_0005fok_0002ejspwrite_0005fok_jsp_6.java:108)\tat org.apache.jasper.runtime.HttpJspBase.service(HttpJspBase.java:119)\tat javax.servlet.http.HttpServlet.service(HttpServlet.java:853)\tat org.apache.jasper.servlet.JspServlet$JspServletWrapper.service(JspServlet.java:177)\tat org.apache.jasper.servlet.JspServlet.serviceJspFile(JspServlet.java:318)\tat org.apache.jasper.servlet.JspServlet.service(JspServlet.java:391)\tat javax.servlet.http.HttpServlet.service(HttpServlet.java:853)\tat org.apache.tomcat.core.ServletWrapper.doService(ServletWrapper.java:404)\tat org.apache.tomcat.core.Handler.service(Handler.java:286)\tat org.apache.tomcat.core.ServletWrapper.service(ServletWrapper.java:372)\tat org.apache.tomcat.core.ContextManager.internalService(ContextManager.java:797)\tat org.apache.tomcat.core.ContextManager.service(ContextManager.java:743)\tat org.apache.tomcat.service.http.HttpConnectionHandler.processConnection(HttpConnectionHandler.java:210)\tat org.apache.tomcat.service.TcpWorkerThread.runIt(PoolTcpEndpoint.java:416)\tat org.apache.tomcat.util.ThreadPool$ControlRunnable.run(ThreadPool.java:498)\tat java.lang.Thread.run(Thread.java:484무엇때문인지 아시는 분은 답변 부탁드립니다.',
#   ()),
#  '#129': ('psrha',
#   '2001-07-30 15:48:59',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'win2000에서 jsp와 mysql연동에서 bad handshake에러',
#   'win2000에서 tomcat과 mysql을 쓰고 있습니다.그냥 일산 사용자 계정없이 그러니까 user와 password를 빈값으로 주고 jsp파일을 돌리면 테이블도 잘 생기고 값도 잘 가져옵니다.String DB_URL = "jdbc:mysql://localhost/test";String DB_USER = "";String DB_PASSWORD= "";Connection conn;Statement stmt;String query = "create table createTest(name varchar(10), tel varchar(15))";Class.forName("org.gjt.mm.mysql.Driver");conn = DriverManager.getConnection(DB_URL, DB_USER, DB_PASSWORD);근데 이와같이 하지 않고..sql 서버에서 사용자 계정을 만들고user테이블과 db테이블 insert해주고 권한 설정도 했습니다.또 올바로 값이 들어가있나 확인도 몇번이나 했습니다..근데 jsp파일을 실행시켜면 계속 bad handshake에러가 납니다String DB_URL = "jdbc:mysql://localhost/lottery";String DB_USER = "psrha";String DB_PASSWORD= "3440";Connection conn;Statement stmt;String query = "create table sangho(name varchar(10), tel varchar(15))";Class.forName("org.gjt.mm.mysql.Driver");conn = DriverManager.getConnection(DB_URL, DB_USER, DB_PASSWORD);이와같은 jsp파일을 실행하면 발생합니다..에러는 java.sql.SQLException: Communication link failure: Bad handshake 입니다.여러군데 돌아다녀봤는데 뚜렷한 해결책이 없네요아시는 분들 답변 부탁드립니다...그럼...',
#   ()),
#  '#130': ('나영미',
#   '2001-07-30 16:02:56',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '사용자 관리에서 500에러입니다....',
#   '사용자 관리를 하고 있습니다.근데....500에러가 나타납니다.>> userprocess.jsp <<Class.forName("org.gjt.mm.mysql.Driver");Connection conn = DriverManager.getConnection("jdbc:mysql://localhost/db명","id","passwd");....................PreparedStatement pstmt = null;pstmt = conn.prepareStatement(jsql);userprocess.jsp 파일이 위와 같이 정의 되어 있거든요.......근데....왜 정의 안됐다고 나타나는지요????보시고 답변부탁합니다.....^o^리눅스 서버를 사용하구 있구요.... telnet상에서 계정을받아서 작업을 하고 있습니다...........(다른 작업을 잘 하고 있되다가..가끔 테스트 하다보면...파일이 없다고 404 에러가 나타납니다. 그런데//서버를 재부팅 하면 다시 잘 나타납니다....왜 그런건지요??? 그렇다고 서버를 계속재부팅 시킬수도 없는일이고...ㅠ.ㅠ 이유가 뭔지 알려주시면 고맙겠습니다...)*** 환 경 ***************************************linux/tomcat/apache/mysql을 사용합니다.*************************************************Error: 500Location: /login/userprocess.jspInternal Servlet Error:org.apache.jasper.JasperException: Unable to compile class for JSP/usr/local/tomcats/tomcat/work/localhost_8080/_0002flogin_0002fuserprocess_0002ejspuserprocess_jsp_0.java:91: Undefined variable or class name: connpstmt = conn.prepareStatement(jsql);^1 errorat org.apache.jasper.compiler.Compiler.compile(Compiler.java:282)at org.apache.jasper.servlet.JspServlet.doLoadJSP(JspServlet.java:612)at org.apache.jasper.servlet.JasperLoader12.loadJSP(JasperLoader12.java:146)at org.apache.jasper.servlet.JspServlet.loadJSP(JspServlet.java:542)at org.apache.jasper.servlet.JspServlet$JspServletWrapper.loadIfNecessary(JspServlet.java:258)at org.apache.jasper.servlet.JspServlet$JspServletWrapper.service(JspServlet.java:268)at org.apache.jasper.servlet.JspServlet.serviceJspFile(JspServlet.java:429)at org.apache.jasper.servlet.JspServlet.service(JspServlet.java:500)at javax.servlet.http.HttpServlet.service(HttpServlet.java:853)at org.apache.tomcat.core.ServletWrapper.doService(ServletWrapper.java:405)at org.apache.tomcat.core.Handler.service(Handler.java:287)at org.apache.tomcat.core.ServletWrapper.service(ServletWrapper.java:372)at org.apache.tomcat.core.ContextManager.internalService(ContextManager.java:797)at org.apache.tomcat.core.ContextManager.service(ContextManager.java:743)at org.apache.tomcat.service.connector.Ajp12ConnectionHandler.processConnection(Ajp12ConnectionHandler.java:166)at org.apache.tomcat.service.TcpWorkerThread.runIt(PoolTcpEndpoint.java:416)at org.apache.tomcat.util.ThreadPool$ControlRunnable.run(ThreadPool.java:501)at java.lang.Thread.run(Thread.java:484)',
#   ()),
#  '#131': ('rucy',
#   '2001-07-30 16:14:53',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'ORA-01017: invalid username/password',
#   '다른 NT 서버에 있는 오라클을 사용해서, Okboard 0.91을 설치하려고 하는데요.classpath는 디비서버에 있는 classes12.zip을 카피해와서 클래스패스에 지정해주었습니다.그럼데 다음과 같은 에러가 나는건...왜일까용...--;답좀 주셔요~~플리즈===================================================ORA-01017: invalid username/password; logon denied..\\classes;..\\lib\\ant.jar;..\\lib\\jasper.jar;..\\lib\\jaxp.jar;..\\lib\\parser.jar;..\\lib\\servlet.jar;..\\lib\\webserver.jar;D:\\IBM Connectors\\classes;D:\\IBMCON~1\\CICS\\Classes\\CTGCLI~1.JAR;.;D:\\Program Files\\SQLLIB\\java\\db2java.zip;D:\\Program Files\\SQLLIB\\java\\runtime.zip;D:\\Program Files\\SQLLIB\\bin;D:\\JDK1.3.1\\LIB\\TOOLS.jar;D:\\mm.mysql.jdbc-1.2c;D:\\JDK1.3.1\\LIB\\classes12.zip;;D:\\JDK1.3.1\\lib\\tools.jartable reset',
#   ()),
#  '#132': ('현정희',
#   '2001-07-30 16:39:22',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '검색하기에서 영문은 되고 한글은 안됩니다.',
#   '다시 올립니다.tomcat 3.2를 쓰고 있습니다. 님 글을 읽고 영문으로 해보니깐 영어는 검색이 됩니다. 한글 처리를 해야하나요?어찌해야하는지............',
#   ()),
#  '#133': ('초보',
#   '2001-07-30 16:49:58',
#   ('java', ' jsp'),
#   ' 4',
#   '0',
#   '배열전송의 방법을 모르겠어요.',
#   '어떤 String x= "$Y11112 5811$Y11108 5811$Y11115 5811$Y11115 5711"  이 있는데요.보면 중복되는 \'$\'라는 글자를 기준으로 배열에 집어넣고 싶거든요.arr[0] = "Y11112 5811";arr[1] = "Y11108 5811";arr[2] = "Y11115 5811";arr[3] = "Y11115 5711";이런 식으로요.방법이 없을까요?',
#   ()),
#  '#134': ('윤지석',
#   '2001-07-30 17:04:02',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '질문입니다.. kenu님...',
#   '안녕하세요 kenu님...조금 빗나간 질몬인지 모르겠지만혹시 jsp 와 플래시의 연동이 가능한지요...기존 웹사이트에서 지금 떠돌고있는 플래시 게시판들은 php와 asp로 제작된걸로 알고 있습니다...제 생각으론 php,asp가 된다면 jsp로 가능할 듯 한데여...또한 플래시 안에서의 액션스크립이 자바 스크립과 아주 흡사하기 때문에 연동이 될거라 생각하는데....저 혹시 조금이라도 정보 있으심 답변주심 감사합니다...',
#   ()),
#  '#136': ('초보자',
#   '2001-07-30 17:25:57',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'jsp와 Oracle8i연동 방법좀 알려 주세요.',
#   'jsp와 Oracle8i Enterprise Edition을 연동하고 싶은데어떻게 해야 되는지요?혹시 아시는 분이나 사이트가 있으면 좀 가르쳐 주세요.부탁 드립니다.',
#   ()),
#  '#14': ('윤지석',
#   '2001-07-26 13:13:21',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'NT tomcat-3.2.3 질문입니다',
#   'kenu님 감사합니다...여기 게시판만 읽어도 충분히 공부가 되네여전 님 강좌를 보고 iis와 같이 연동하고 있습니다..전 iis를 요번에 첨 접해서 잘 모르겠어여..님 강좌 고대로 했습니다http://localhost  =>> 옛날 asp 홈피가 나옵니다..http://localhost:8080  => 지금의 jsp 홈피가 나옵니다..server.xml화일에서 8080을 default인 80으로 고치면 톰켓이 죽어버립니다.어떻게 해야할지..옛날 홈피를 jsp로 교체하고 있는데, 마음같아선 iis를 죽이고 톰켓으로만 돌리고 싶지만 iis로 돌리고 있는 email서비스가 안되니 말이져..참고로 d:\\inetpub\\wwwroot 폴더 밑에 옛날 asp 화일이 있고d:\\jsphome폴더에 jsp 화일이 있습니다..',
#   ()),
#  '#141': ('푸쉬카르',
#   '2001-07-30 18:05:06',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '프레임으로 나뉘어 있는 페이지에 session을 적용하려면..',
#   '프레임으로 나뉘어 있는 페이지에 session을 적용하여..로그인하지 않으면.. 로그인 페이지로 넘어가도록 하려고 하는데.. 가능한 방법이 없을까요..프레임이 html만의 특성인지.. 문서를 jsp로 바꾸고... session 처리를 하니깐.. 적용이 안되더라구요..그렇다고.. 프레임 중 메인 부분에 session 처리를 하니까.. 창 전체적으로 로그인 화면이 뜨지 않고.. 그 메인 부분 일부에만.. 로그인 화면이 떠서.. 문제가 되더군요..혹시 아시면.. 답변 부탁드립니다..',
#   ()),
#  '#142': ('쉼터',
#   '2001-07-30 18:34:13',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '알고리즘에 강한 자바고수들만 보세요!!!(쉬어가는 페이지)',
#   '아래의 프로그램을 보세요.public class toCharArray{\tpublic static void main(String[] args)\t{\t\tString str = "Y11112 5811$Y11108 5811$Y11115 5811$Y11115 5711&";\t\t\tString sss = new String();\t\tString[] aaa = new String[15];\t\tint j = 0;\t\tchar[] ch = str.toCharArray();\t\tfor(int i = 0;i<ch.length;i++)\t\t{\t\t\tif(ch[i] != \'$\')\t\t\t\tsss += ch[i];\t\t\telse\t\t\t{aaa[j] = sss;\t\t\tj++;\t\t\tsss ="";}\t\t}\t\tfor(int i = 0;i<4;i++)\t\tSystem.out.println(aaa[i]);\t}}정답이Y11112 5811Y11108 5811Y11115 5811null입니다.왜Y11112 5811Y11108 5811Y11115 5811Y11115 5711가 아닐까요?',
#   ()),
#  '#143': ('hinehong',
#   '2001-07-30 18:48:48',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '좀 봐주셈..ㅡ.ㅡ;',
#   '로그인을 만들려고 소스를 보았는데 계속 같은 화면으로 그런 아이디가없다는 화면이 출력되는군여.. 흠 빈즈에서 if((useridx.equals(userid)) && (passwordx.equals(password)) {              return true;             이렇게 비교를 했습니다. useridx passwordx 가 디비에 들어있는 자료             userid password 가 웹에 적은 자료입니다.jsp파일에서 그걸..            hineuserid = request.getParameter("userID");            hinepassword = ...........................;            boolean value = mylogin.validateUser(hineuserid,hinepassword);mylogin 은 빈즈 아이디 이렇게 해서         if (valid==true) {         session=request.getSession(true);         session.putValue("userID",hineuserid);그인을 만들려고 소스를 보았는데 계속 같은 화면으로 그런 아이디가없다는 화면이 출력되는군여.. 흠 빈즈에서 if((useridx.equals(userid)) && (passwordx.equals(password)) {              return true;             이렇게 비교를 했습니다. useridx passwordx 가 디비에 들어있는 자료             userid password 가 웹에 적은 자료입니다.jsp파일에서 그걸..            hineuserid = request.getParameter("userID");            hinepassword = ...........................;            boolean value = mylogin.validateUser(hineuserid,hinepassword);mylogin 은 빈즈 아이디 이렇게 해서         if (valid==true) {         session=request.getSession(true);         session.putValue("userID",hineuserid);비교를 못하고 있어여 디비랑 사용자가 입력한거랑..좀 갈켜 주셈..',
#   ()),
#  '#145': ('오현우',
#   '2001-07-30 19:40:06',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '[질문] 서블릿을 호출하여 jsp로 화면에 뿌려주는데...',
#   '제목대로 servlet을 호출하여, 결과를 jsp 화일로 넘겨서 화면에 뿌려주려합니다.이럴때 , 이 서블릿에 연결된 jsp 화일의 위치는 어디가 되는지?서블릿의 소스는 다음과 같습니다.package com.taglib.wdjsp.arch;import java.io.*;import javax.servlet.*;import javax.servlet.http.*;public class HelloWorldServlet extends HttpServlet{        public void service(HttpServletRequest req, HttpServletResponse res) throws ServletException, IOException        {                String theMessage = "Hello, world";                String target = "helloFromServlet.jsp";                req.setAttribute("message", theMessage);                RequestDispatcher rd;                rd = getServletContext().getRequestDispatcher(target);                rd.forward(req, res);        }}',
#   ()),
#  '#153': ('김용휘',
#   '2001-07-31 00:59:29',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'oci8 driver 좀 올려주세요...',
#   '글을 올리는 데 varchar2(4000) 으로 잡았는데실제 올라가는 글의 용량은 2000byte 밖에 되지 않는데그이유는 thin driver에서는 지원을 못한다고하던데 그말이 맞습니까....그래서 동료 들에게 물어 보니 oci8 driver를 써면 4000byte까지 올리수 있다고 하던데 그말도 맞는지요.다른 방법이 없으면 table을 두개 나눠야 한다든데요정확하게 어떻게 프로그램을 짜야 하는지 모르겠습니다.혹시 소스게시판 말고 좀더 자세히 글을 올려 주실수 있는지요.그렇게 해 주시면 정말 고맙겠습니다.많은 동료에게도 이 사이트를 소개 시켜드리겠습니다.답변 부탁드립니다....그럼 이사이트의 무한한 발전이 있기를......',
#   ()),
#  '#157': ('청사',
#   '2001-07-31 09:22:13',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '아파치와톰켓의 관계',
#   '안녕하세요.아파치와 톰켓의 관계를 정확하게 알고 싶습니다.대충 아파치는 web server 톰켓은 servlet를 구현하는 server정도로만 알고 있습니다. 이것도 제대로 알고 있는지는 모르지만요!두가지를 정확하게 이해를 하고 싶거든요! ㅎㅎ부탁드립니다.그럼 수고 하시기 바랍니다.',
#   ()),
#  '#161': ('에어울프',
#   '2001-07-31 10:06:20',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '오늘 입력된 총글수 쿼리문(질문)',
#   '어제 질문글 중 ms sql이라는 단서를 붙이지 못했습니다.select count(*) from bbs where to_char(todate,\'yymmdd\') = to_char(sysdate,\'yymmdd\')이 내용이 ms sql용입니까?프로그램에 적용했더니\'to_char\' is not a recognized function name.이런 메세지가 나옵니다.다시한번 부탁드립니다.--kenu 님의 글 [01-07-30 (12:38:58)]>select count(*) from bbs where to_char(todate,\'yymmdd\') = to_char(sysdate,\'yymmdd\')>쿼리 한방입니다.>>--에어울프 님의 글 [01-07-30 (11:11:45)]>>안냐세요..>>계속 님의 도움을 받고 있는 허접입니다.>>게시판을 바꾸셨네요..>>한가지 문의할 것은 오늘 입력한 글의 총 갯수를 구하는 방법인데요..>>날짜가 db에 저장될때 datetime형식으로 저장됩니다.>>이걸 쿼리해서 오늘 날짜와 비교를 해서 오늘 입력한 글의 갯수를 구하고 싶습니다.>>그런데 db에 입력된 날짜는 보기에는 2001-07-30 오전.... 이런 형식으로 보여지지만 실제는 그게 아닌거 같습니다.>>>>Date today = new Date();>>SimpleDateFormat formatter = new SimpleDateFormat("yyyy-MM- dd");>>int total = 0;>>query = "select count(*) from bbs where todate like \'%(formatter.format(today))%\'";>>>> pstmt = dbCon.prepareStatement(query);>> rs = pstmt.executeQuery();>>>> if(rs.next())>> total = rs.getInt(1);>> rs.close();>>>>이런식으로 하면 도저히 원하는 결과를 찾을 수 없습니다.>>오늘 글의 갯수를 구하는 좋은 방법이 있으면 가르쳐 주세요..>>수고하세요.....',
#   ()),
#  '#162': ('파워짱',
#   '2001-07-31 10:31:33',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '날짜의 차이구하는 법을 알려주세요',
#   '날짜를 input입력화면으로 2개를 받아서 날짜의 차이를 계산하는 방법과 input날짜로 부터 일정한 날짜를 더하여 그 날이 몇칠인지를 계산하는 방법을 알고자 합니다.. ex) 화면상으로 받은 날짜 1 : 2001.07.20     화면상으로 받은 날짜 2 : 2001.06.20    했을때의 날짜의 차이를 구하는 법과            2001.07.20 - 2001.06.20 = 날짜차이     문법상으로 명괘하게 풀어주세요  화면상으로 받은날짜 1: 2001.07.20 + 30일을 더하는 방법을  자세하게 알려주시고 고맙겠습니다.  고수님들 부탁드립니다.',
#   ()),
#  '#163': ('김재환',
#   '2001-07-31 10:52:48',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '게시판에서 10개씩 쿼리 가져오는 것에 대해서',
#   '게시물에서 10개씩 쿼리 가져오는 것을 테스트 해 보았습니다.그런데 위의 것은 단변형이 없는 게시판에서는 유용하지만 단변형 게시판에서는 문제가 있다고 생각합니다.단변형에 대해서 10개씩 가지고 오는  것이 있으면 갈켜주세요',
#   ()),
#  '#166': ('자바허접매니아',
#   '2001-07-31 11:16:32',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '벡터?? 벡터!!  푸학!!  도와도요오오오오오~~',
#   '여전히 케누님은 열정을 다하고 계시네요.가끔씩 들러서 글 많이 읽고 가면 도움이 무지된답니다.앞으로 계속 신경써주세요.. 예빈이는 건강한지요?? ^^;그럼..-------------------------------------------------------움화화.무식하게 코딩해온 습관이 드디어 일을 저질렀습니다.벡터에대한 개념을 잡자마자.. 한번 해보겠다고 플그램을짜기 시작했는데...문제는..벡터로 디비안의 내용을 for문을 사용하여 jsp에서 한줄씩 뿌려주고 있는 간단한 프로그램인데. 여기에 정렬 쿼리를 첨가해서,이름별, 위치별로 정렬을 했습니다.근데.. 같은 이름일때 따로 묶어서 합계를 보여주고(중간합), 위치별일때 따로 묶어서 합계를 보여주는 로직을 설계중인데..중간합계를 결과값 중간중간에 보여지게끔 이름      데이터  A          23  A          12중간합       35  B          11중간합       11  C           1  C           3  C           2중간합        6설계를 하고 싶은데.. flag를 사용하다가... 지금..머리가 너무 아파서 잠시 쉬는중입니다.JSP단에서 모두 해결할만한 팁이나, 대안있으시면 부탁드립니다.',
#   ()),
#  '#170': ('당근',
#   '2001-07-31 14:05:45',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '웹브라우저에서 새로고침을 연달아 여러번하면 톰켓이 죽는이유가 뭔지?',
#   '톰켓이 죽는 이유가 뭔지모르겠어요제가 생각하기에는 동시접속자수와 연관이 있는것같은데요새로고침을 여러번 연달아하면 톰케이 죽는 데요해결방법좀갈켜주세요',
#   ()),
#  '#174': ('안철한',
#   '2001-07-31 15:27:00',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '동적 클래스?',
#   '제가 어는 사이트에서 글을 읽다가 다음과 같은 글을 보고 질문을 드립니다."대부분의 Servlet, JSP 환경에서 CLASSPATH에 지정된 디렉토리의 클래스 파일들은 수정 시 reload가 되지 않으므로 꼭 자신의 환경 설정 파일에서 지정하는 동적 클래스 파일 디렉토리에 세 파일을 위치하도록 한다."여기서 말하는 동적 클래스를 설정하기 위해서는 Tomcat에서는 어떻게 해야 하는지 가르쳐 주시면 감사 하겠습니다.',
#   ()),
#  '#176': ('박선형',
#   '2001-07-31 16:21:31',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'ksc5601과 ecu-kr의 차이점은 무엇입니까?',
#   '안녕하세요?JSP스크립트와 HTML이 같이 섞여들어간 파일에서KENU 님이 알려주신 부분에서<%@ page import="java.net.*" contentType="text/html; charset=ecu-kr" %>을 쓰면 한글이 깨져서 나오고<%@ page import="java.net.*" contentType="text/html; charset=ksc5601" %>로변경시켰더니 한글이 제대로 나옵니다.그리고 HTML과 FORM양식이 들어가는 파일에선<%@ page import="java.net.*" contentType="text/html; charset=ecu-kr" %>을 포함시켜줘야만 한글이 깨지지 않고 나오더군요.ksc5601과 ecu-kr의 차이점은 무엇입니까?kenu님이 알려주신<%@ page import="java.net.*" contentType="text/html; charset=ecu-kr" %>문장좀 해석해주시겠어요?감사합니다.',
#   ()),
#  '#177': ('에어울프',
#   '2001-07-31 16:25:04',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '(질문)이 문제좀 해결해 주세요..',
#   "밑에 글을 올렸는데 바쁘신지 답글이 없네요..꼭 좀 부탁드립니다.select count(*) from bbs where to_char(todate,'yymmdd') = to_char(sysdate,'yymmdd')이렇게 하면 오늘 입력한 글의 총갯수를 구할 수 있다고 하셧는데 그대로 하면'to_char' is not a recognized function name.이런 에러메세지가 나옵니다.아마 함수가 정의되어 있지 않다고 하는것 같습니다.제 db는 ms sql이고 to_char에 관한 함수가 정의된 소스가 있으시다면 부탁드리겠습니다.아니면 다른 방법이라도 알려 주셨으면 합니다.즐거운 하루 되세요......",
#   ()),
#  '#179': ('설대근',
#   '2001-07-31 16:46:42',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '한글 문제 입니다.제발 제발 도와 주세요.. 아.. 잠잔지가 언제인가....',
#   '안녕하세요 제 이름은 설대근이구요 (이름이 특아하죠...^^);wnidows2000pro 에서 Resin2.0.0과 Apache1.3.20 그리고 DB는 winMySQLadmin1.1 & (jdbc)을사용하고 있습니다.저는 요즘 회원BBs를 만들고 있는데 DB 사용시 한글에 만 문제가 있어서 도움을 부탁 드립니다.<제가 한 방식을 설명 드리자면.>한글 코드 선언 -------------------------<%@ page contentType="text/html;charset=euc-kr"import="java.sql.*" %>포스트 방식으로 값을 가지고 와서 ----------------String   name = request.getParameter("name")쿼리문 작성-------------------------------------------String jsql = "insert into bbslist(username) values(?)";pstmt = con.prepareStatement(jsql);DB에 값넣어주기pstmt.setString(1,name);퀴리문 실행-------------------------------------------pstmt.executeUpdate();문제점 .....................이렇게 하면 실행은 되는데 일딴 한글이 깨져서 저장이 되구요검색해서 값을 가지고 올때도 깨져서 값을 받아와요..//그리고 한가지더 이게 진짜 질문입니다.jsp 를 통해서 DB에 데이터를 입력하면 나중에 검색하면 값을 찾고 그 값을 받아 옵니다.하지만 우편번호 DB와 같이 mysql 자체어서 저장한 데이터는 검색 조차 되지 않터군요.제발 도와 주세요이것 땜시 3일 동안 밤을 셋습니다.제발 가르쳐 주세요 .잠좀 자게.. 제발요..........................고수님들 필독\'',
#   ()),
#  '#185': ('박선형',
#   '2001-07-31 17:34:03',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'JSP에서 주석처리는 어떻해 해야 되는지,,',
#   '안녕하세요?JSP에서 여태 // 를 주석문으로 사용하다보니여러 줄을 할 때 많은 애를 먹었는데요,그래서 책에 있는데로<%----%> 을 사용했더니 주석문이 아닌듯 주석처리가 안되었더군요.JSP스크립트내에서 여러줄을 간단히 주석 처리 할 수 있는 방법좀 알려주세요항상 좋은 답변 해주시는 KENU님께 감사합니다.^^',
#   ()),
#  '#186': ('elfkh',
#   '2001-07-31 17:43:04',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '게시판 깔끔.. & Kenu님..',
#   '게시판이 깔끔하게 바뀌었네염..이쁘당..근데.. 세팅에 필요한 프로그램 링크가 다 에러가 나네염..한번 봐주세염..꼭여..',
#   ()),
#  '#188': ('neem',
#   '2001-07-31 18:30:45',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'servlet이 실행안되네요. 갈켜주세요.',
#   'asp를 배우다 jsp를 배우기 시작했어요.톰켓에서jsp페이지는 실행되는데 servlet은 실행이 안되네요.제공된 예제도 .class파일을 삭제하면 파일을 찾을수 없다는에러가 뜹니다.servlet을 컴파일할수 없는것 같은데어찌하면 되겠어요.갈켜주셨으면 감사하겠습니다.',
#   ()),
#  '#189': ('이정석',
#   '2001-07-31 18:53:31',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '질문이요...',
#   'jsp하구 oracle8i연동하려고 하는데 잘 안됩니다. 브라우저에첫 번째 행만 나타나고, db로 로딩하는 부분이 나타나지 않네요... 한 번 봐주세요.<%@ page contentType="text/html;charset=euc-kr"    import="java.sql.*"\terrorPage="error.jsp"%><html><head><title>Player table search</title><meta http-equiv="Content-Type"     content="text/html; charset=euc-kr"><style type="text/css"><!--.normal{ font-family: "굴림", "돋움"; font-size:x-small; font-style:normal;font-weight:normal; text-decoration:none}.normalbold{ font-family:"굴림","돋움"; font-size:x-small; font-style:normal;font-weight:bold;text-decoration:none}--></style></head><body bgcolor="#FFFFFF"><%   Class.forName("oracle.jdbc.driver.OracleDriver");   String url="jdbc:oracle:thin:@163.152.216.101:1521:kucsdb";   Connection testCon=DriverManager.getConnection(url,"synus1","9680");   String jsql="select * from Player";   Statement stmt=testCon.createStatement();   ResultSet rs=stmt.executeQuery(jsql);%><p class="normalbold">Player table search(SELECT * FROM Player) </p><table width="90%" border="1" cellspacing="0" cellpadding="0" bordercolor="#000000">  <tr bgcolor="#CCCCFF" class="normalbold">    <td>\t  <div align="center">BackNumber</div>\t  </td>\t  <td>       <div align="center">Name</div>\t   </td>\t   <td>\t   <div align="center">Team_Name</div>\t   </td>\t   <td>\t   <div align="center">AVG</div>\t   </td>\t   <td>\t   <div align="center">Strike_Out</div>\t   </td>\t   </tr><%  while(rs.next()){%>  <tr class="normal">\t<td>\t   <div align="center"> <%=rs.getInt(1)%></div>\t</td>    <td>\t  <div align="center"> <%=rs.getString(2)%></div>\t</td>\t<td>      <div align="center"> <%=rs.getString(3)%></div>\t</td>\t<td>\t  <div align="center"> <%=rs.getFloat(4)%></div>\t</td>\t<td>\t   <div align="center"> <%=rs.getInt(5)%></div>\t</td>  </tr>  <%     }      rs.close();      testCon.close();  %>  </table>  </body>  </html>',
#   ()),
#  '#2': ('haegni59',
#   '2001-07-25 16:45:14',
#   ('db', ' 데이터베이스'),
#   ' 0',
#   '0',
#   'Windows 2000 + oracle 8.1.5 JDBC 설정 도와주세요.',
#   '더운데 수고가 많으십니다...다름이 아니고, 제가 이번에 2000에다가 오라클을 깔았는데, jdbc 연결이 안되더라구요...에러는 다음과 같이 나타납니다.java.lang.ClassNotFoundException : oracle.jdbc.driver.oracleDriver.......다른 사이트에 98 + oracle 설치방법을 참고해서 설치했는데 잘 안됩니다..도와주세요...저는 현재 이 사이트에 나와 있는 설정대로 win2000 pro + resin-2.0.0 + iis 를 설치하였습니다.참고로 제 classpath 설정은 다음과 같습니다.;C:\\Oracle\\Ora81\\jdbc\\lib\\classes111.zip;C:\\JDK1.3.1\\LIB\\tools.jar;C:\\JDK1.3.1\\LIB\\mail.jar;C:\\JDK1.3.1\\LIB\\activation.jar;;%CLASSPATH%;.그럼 수고하세요.',
#   ()),
#  '#205': ('박선형',
#   '2001-07-31 21:06:52',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'IIS5.0과 톰켓을 돌리면 DB에 저장할때 한글 변환되는지요?',
#   '지금 게시판을 만들고 있는데DB에 날짜를 한글로 저장하지 못해서 애먹고 있거든요.IIS5.0과 톰켓을 돌리면 DB에 저장할때 한글 변환하는 코딩 써줄 필요 없는지 알구 싶습니다.',
#   ()),
#  '#206': ('박수형',
#   '2001-07-31 23:05:49',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '서블릿과 jsp연동에 관해서',
#   '자바엔진은: tomcat이고,jdk1.3 을 쓰고 있습니다.다름이 아니라..서블릿에서 jsp파일을 호출하려고 하는데자꾸 에러가 나서..이렇제 조언을 부탁드립니다.밑에 보시면 제가 한 코딩이 있는데 뭐가 잘못된게 있습니까?서블릿에서 수행해서..값도 id부분만 가져가면 되는데..jsp호츨 되는부분이 자꾸에러가 나서..import javax.servlet.*;import javax.servlet.http.*;import java.io.*;import java.sql.*;        public class Login extends HttpServlet        {             private PrintWriter writer = null;\t\t\t String id,passwd;\t\t\t Login join = null;\t\t\t\t\t\tpublic void doGet(HttpServletRequest req,HttpServletResponse res)\t\t\t\t\t\t           throws ServletException,IOException\t\t\t\t\t\t{\t\t\t\t\t\t    id = req.getParameter("id");\t\t\t\t\t\t\tpasswd = req.getParameter("passwd");\t\t\t\t\t\t\twriter = new PrintWriter(res.getOutputStream(),true);\t\t\t\t\t\t\t  \tDatabase db = new Database();\t\t\t\t\t\t\t\tif (db.isMember(id,passwd))  // 회원인지 아니지 구별하는 메소드..회원이면 밑에 있는부분실행\t\t\t\t\t\t\t\t{\t\t\t\t\t\t\t\t RequestDispatcher rd;\t\t\trequest.setAttribute("id");\t\t\t\t\t rd = getServletContext().getRequestDispatcher("/login.jsp");\t\t\t\t\t\t\t\t rd.forward(req,res);\t\t\t\t\t\t\t\t}\t\t\t\t\t\t\t\telse\t\t\t\t\t\t\t\t{\t\t\t\t\t\t\t\twriter.println("아이디나 비밀번호가 일치하지 않습니다");\t\t\t\t\t\t\t\t}\t\t\t\t\t\t}',
#   ()),
#  '#207': ('이정석',
#   '2001-08-01 02:37:57',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '질문이요.',
#   'jsp와 oracle8i연동하는데. 아까 질문했던내용에서요...근데 db에 생성된 table을 다른 걸로 바꿀 때 마다되는 것도 있고, 안되는 것도 있어요. 이것이 어떻게된거죠? 아래와 같은 table은 안되네요.SQL> describe Player 이름                                      널?      유형 ----------------------------------------- -------- ---------------------------- BACKNUMBER                                NOT NULL NUMBER(3) NAME                                               VARCHAR2(8) TEAM_NAME                                          VARCHAR2(15) AVG                                                NUMBER(4,2) STRIKE_OUT                                         NUMBER(3)그리고 아래 table는 되거든요...SQL> describe student 이름                                      널?      유형 ----------------------------------------- -------- ---------------------------- STUDENT_ID                                NOT NULL VARCHAR2(20) LAST_NAME                                 NOT NULL VARCHAR2(25) FIRST_NAME                                NOT NULL VARCHAR2(25) MI                                                 VARCHAR2(1) YEAR                                               VARCHAR2(25) STREET_ADDRESS                                     VARCHAR2(25) CITY                                               VARCHAR2(25) STATE                                              VARCHAR2(2) ZIPCODE                                            VARCHAR2(9) TELEPHONE                                          VARCHAR2(10) FAX                                                VARCHAR2(10) EMAIL                                              VARCHAR2(100)',
#   ()),
#  '#208': ('민규`',
#   '2001-08-01 03:05:36',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'kenu 님 ~',
#   'KENU 님 방가 ~~~ 저 msn에 "짜장면 시키신분~"이에요..항상msn에서 뵙지만.. 올만에 들어왔는데 여기 게시판 넘 깔끔하구이쁘네요 ~~헤헤 ~~ 넘 늦게 인사를 했다구여~~? ^^ 요즘 알바하느라 바뻐서 잠시 속세를 떠났거덩여 .... 암턴!!! 앞으로도 모르는거 마아니 마아니 ~~ 물볼꼐용 ~~ 바바이',
#   ()),
#  '#209': ('금현이',
#   '2001-08-01 09:50:25',
#   ('java', ' jsp'),
#   ' 1',
#   '0',
#   '책에 대한문의입니다.',
#   '저번에 어디선가 읽었는데 kenu님께서 jsp는 jspbible책이 좋다고 하셨는데 제가 틀린것은 아닌지 알고싶어요.webdox에서 지은책 맞죠?그럼 혹시 ejb책도 보셨나요?ejb책도 jspbible책처럼 강추인가요? 먼저 읽어보신분들의 의견을 듣고싶어서 질문 드립니다.',
#   ()),
#  '#210': ('배정윤',
#   '2001-08-01 09:50:32',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '[질문]apache깔구 http://localhost/하면....',
#   '원래는 apache 깔구 httpd.conf에서 servername하구 documentroot만 설정해주면 웹 브라우저에서  http://localhost/ 라고 치면 default페이지 떠야 하잖아요...근데...그렇게 안되고.........이 페이지를 볼 수 있도록 승인되지 않았습니다.이런 메세지만 계속 떠요...그래서 http://나의 IP/ 또는  http://127.0.0.1/ 도 해봤는데 똑같아요.지금 5번 깔았다가 지웠는데..왜이렇죠?알려주세여....권한이 없는 건가...?만약 권한이 없는 거라면 어디서 권한을 줘야 하는 건가요?참고로 저는 windowsNT 4.0사용자 입니다.',
#   ()),
#  '#215': ('몰라알수가없어',
#   '2001-08-01 10:49:53',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '에러구문..ORA-01722: 수치가 부적합합니다',
#   '이런 에러는 어떤 경우에 일어나는지 궁금하군요소스는 다른 컴에서 잘 돌아가고 있는것입니다.tomcat3.2/oracle8.6/win2000입니다.oracleDB는 원격으로 연결하고요~javax.servlet.ServletException: ORA-01722: 수치가 부적합합니다\tat org.apache.jasper.runtime.PageContextImpl.handlePageException(PageContextImpl.java:459)\tat _0002fcat_0005flist_0002ejspcat_0005flist_jsp_0._jspService(_0002fcat_0005flist_0002ejspcat_0005flist_jsp_0.java:194)\tat org.apache.jasper.runtime.HttpJspBase.service(HttpJspBase.java:119)\tat javax.servlet.http.HttpServlet.service(HttpServlet.java:853)\tat org.apache.jasper.servlet.JspServlet$JspServletWrapper.service(JspServlet.java:177)\tat org.apache.jasper.servlet.JspServlet.serviceJspFile(JspServlet.java:318)\tat org.apache.jasper.servlet.JspServlet.service(JspServlet.java:391)\tat javax.servlet.http.HttpServlet.service(HttpServlet.java:853)\tat org.apache.tomcat.core.ServletWrapper.doService(ServletWrapper.java:404)\tat org.apache.tomcat.core.Handler.service(Handler.java:286)\tat org.apache.tomcat.core.ServletWrapper.service(ServletWrapper.java:372)\tat org.apache.tomcat.core.ContextManager.internalService(ContextManager.java:797)\tat org.apache.tomcat.core.ContextManager.service(ContextManager.java:743)\tat org.apache.tomcat.service.http.HttpConnectionHandler.processConnection(HttpConnectionHandler.java:210)\tat org.apache.tomcat.service.TcpWorkerThread.runIt(PoolTcpEndpoint.java:416)\tat org.apache.tomcat.util.ThreadPool$ControlRunnable.run(ThreadPool.java:498)\tat java.lang.Thread.run(Thread.java:484)Root cause:java.sql.SQLException: ORA-01722: 수치가 부적합합니다\tat oracle.jdbc.dbaccess.DBError.throwSqlException(DBError.java:114)\tat oracle.jdbc.ttc7.TTIoer.processError(TTIoer.java:208)\tat oracle.jdbc.ttc7.Oall7.receive(Oall7.java:542)\tat oracle.jdbc.ttc7.TTC7Protocol.doOall7(TTC7Protocol.java:1311)\tat oracle.jdbc.ttc7.TTC7Protocol.parseExecuteDescribe(TTC7Protocol.java:595)\tat oracle.jdbc.driver.OracleStatement.doExecuteQuery(OracleStatement.java:1600)\tat oracle.jdbc.driver.OracleStatement.doExecute(OracleStatement.java:1758)\tat oracle.jdbc.driver.OracleStatement.doExecuteWithTimeout(OracleStatement.java:1805)\tat oracle.jdbc.driver.OracleStatement.executeQuery(OracleStatement.java:410)\tat _0002fcat_0005flist_0002ejspcat_0005flist_jsp_0._jspService(_0002fcat_0005flist_0002ejspcat_0005flist_jsp_0.java:115)\tat org.apache.jasper.runtime.HttpJspBase.service(HttpJspBase.java:119)\tat javax.servlet.http.HttpServlet.service(HttpServlet.java:853)\tat org.apache.jasper.servlet.JspServlet$JspServletWrapper.service(JspServlet.java:177)\tat org.apache.jasper.servlet.JspServlet.serviceJspFile(JspServlet.java:318)\tat org.apache.jasper.servlet.JspServlet.service(JspServlet.java:391)\tat javax.servlet.http.HttpServlet.service(HttpServlet.java:853)\tat org.apache.tomcat.core.ServletWrapper.doService(ServletWrapper.java:404)\tat org.apache.tomcat.core.Handler.service(Handler.java:286)\tat org.apache.tomcat.core.ServletWrapper.service(ServletWrapper.java:372)\tat org.apache.tomcat.core.ContextManager.internalService(ContextManager.java:797)\tat org.apache.tomcat.core.ContextManager.service(ContextManager.java:743)\tat org.apache.tomcat.service.http.HttpConnectionHandler.processConnection(HttpConnectionHandler.java:210)\tat org.apache.tomcat.service.TcpWorkerThread.runIt(PoolTcpEndpoint.java:416)\tat org.apache.tomcat.util.ThreadPool$ControlRunnable.run(ThreadPool.java:498)\tat java.lang.Thread.run(Thread.java:484)',
#   ()),
#  '#218': ('김재환',
#   '2001-08-01 11:15:28',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '10개씩 쿼리 하는 것에 대해서',
#   '10개씩 쿼리를 하는데는 성공을 했습니다.한가지 궁금한 것은 게시판에서 보통 찾기 메뉴를 통해서 찾기를하는데 이때도 10개씩 쿼리를 하는 것입니까제 생각엔 찾기는 우선 게시물에서 찾아야 하기 때문에 10개씩쿼리를 적용 할 수 없다고 생각하는데빠른 답변 기다리겠습니다.',
#   ()),
#  '#220': ('처버^^a',
#   '2001-08-01 11:24:30',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'iis와 resin의 연동에서...',
#   'iis와 resin을 연동하여 jsp파일을 호출하는중 80(8080포트를 적지않고)포트로 연결하여 바로 호출 할 수있도록 하는 문제에서 post방식으로 submit이 되지 않는다고 몇번이나 질문을 올렸지만, 뚜렷한 답변이 없는 중에 드뎌 해결이되었습니다.저에게는 버젼의 문제이더군요.  resin1.2.7, 1.2.8, 2.0.0, 2.0.1로 해보았지만, 안되어서 예전에 가지고 있던 1.2.2를 사용했더니 해결이 되었습니다.근데, 문제는 저만 그런지 궁금합니다.  지금은 caucho에 가도 1.2.2버젼은 없는 상태에서 저와 같은 문제가 발생한 사람은 없는지 말입니다.  혹시라도 저와 같은 경우를 겪고 해결하신 분은 해결 방법 좀 알려주세요.  그리고 저와 같은 경우를 겪고 계신분은 참고해주시고요...^^;더욱 발전하는 OKJSP가 되기를....',
#   ()),
#  '#223': ('인혁',
#   '2001-08-01 16:59:02',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '중복문제',
#   '님 소스를 보니 파일 중복부분이 바뀐거 같습니다.예전에는 시간이 들어갔는데 이제는 디렉토리를 따로 만들어서저장하시나요?제가 잘본것인지 궁금합니다.그럼.',
#   ()),
#  '#227': ('공창우',
#   '2001-08-01 20:20:33',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '톰켓에러인데...도와주세요.',
#   'Directory Listing for:/Subdirectories:      manual/           Error: 500Location: /Internal Servlet Error:java.io.IOException: Not an ISO 8859_1 character:화\tat org.apache.tomcat.core.BufferedServletOutputStream.print(BufferedServletOutputStream.java:221)\tat org.apache.tomcat.request.DirHandler.doService(StaticInterceptor.java:687)\tat org.apache.tomcat.core.Handler.service(Handler.java:287)\tat org.apache.tomcat.core.ServletWrapper.service(ServletWrapper.java:372)\tat org.apache.tomcat.core.ContextManager.internalService(ContextManager.java:797)\tat org.apache.tomcat.core.ContextManager.service(ContextManager.java:743)\tat org.apache.tomcat.service.http.HttpConnectionHandler.processConnection(HttpConnectionHandler.java:213)\tat org.apache.tomcat.service.TcpWorkerThread.runIt(PoolTcpEndpoint.java:416)\tat org.apache.tomcat.util.ThreadPool$ControlRunnable.run(ThreadPool.java:501)\tat java.lang.Thread.run(Thread.java:484)',
#   ()),
#  '#229': ('최재혁',
#   '2001-08-01 23:59:50',
#   ('db', ' 데이터베이스'),
#   ' 0',
#   '0',
#   'Tips에서요. pl/sql로 메일보내기가 있던데...',
#   'UTL_SMTP.CONNECTION 이 어떤건지 궁금합니다.',
#   ()),
#  '#23': ('윤지석',
#   '2001-07-26 14:29:45',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'kenu 님',
#   '님 답변 정말 감사합니다..강좌(win2k server + IIS + tomcat 3.2.3 )대로 결과까지 확인했습니다(http://localhost/examples/jsp/index.html)context 추가하기에서 강좌대로 설정을 다했습니다..도스창에서 net stop jakarta를 치면시스템 오류 1060지정된 서비스가 설치된 서비스로는 없습니다.그래서 startup.bat를 실행했더니 그냥 죽어버리더라구여(아까 8080부분을 주석처리했거든여)어디가 잘못되서 서비스를 찾을수 없다고 나올가여...저 혼자 모든걸 해결해야하니...kenu님 도와주세여...',
#   ()),
#  '#230': ('서영빈',
#   '2001-08-02 00:28:31',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'tomcat shotdown 이 안됩니다 ... ㅠㅠ;;;',
#   "winme 에 톰켓 잘 구동되고 아파치랑 연동 이상없고 ....이것저것 해보다가 .... 끌려고shotdown.bat 를 실행시키니 ....'환경변수를 저장할 공간이 부족합니다' 라는 메시지가 뜨면서당최 shotdown 이 안됩니다.그럼 이만 즐웹 돼세요",
#   ()),
#  '#232': ('jsp',
#   '2001-08-02 05:54:55',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '톰캣을 재실행해야만..',
#   '서블릿등의 파일을 수정하고..다시 읽어와두 예전의 문서를 읽어옴니다..그래서 톰캣을 재실행해야만.. 제대로 읽어오는데여..자료를 찾아보니..무슨 톰캣이랑..jdk랑 버전이 안맞아서 그런 경우가 있다고 하던뎅..실제루 wrapper.properties에 보니깐..jdk1.2.*등의 문장이 보이긴 하는뎅..이게 톰캣이.. jdk1.2를 인식한다는 건가여?그럼 그 버전은 어케 맞춰주나여?저는 아파치 + 톰캣3.2.1 + jdk1.3 임니당..',
#   ()),
#  '#234': ('인혁',
#   '2001-08-02 09:26:34',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '그런데..',
#   '제가 여기 게시판에 똑같은 화일을 올렸는데 화일 이름이 같게 나오네요..이건 어떻게 된거죠?여기 게시판이 kboard아닌가요?먼저 kboard0.9소스에서는 rename()이 없는거 같은데..0.5는 rename()가 있고요..먼저 0.9소스입니다.String savePath = "/upload";\tString filename = myUpload.getFiles().getFile(0).getFileName();\tString maskname = ""+System.currentTimeMillis();\tint    filesize = myUpload.getFiles().getFile(0).getSize();\tif(filesize>0) {\t\ttry {\t\t\tmyUpload.getFiles().getFile(0).saveAs(savePath+"/"+maskname);\t\t} catch (Exception e) {\t\t\tSystem.out.println(e.getMessage());\t\t} // end try---------------------------------------------------------0.51소스입니다.<%\t// Initialization\tmyUpload.initialize(pageContext);\t// Upload\tmyUpload.upload();\tString savePath = "c:/jsphome/upload/";\tString filename = myUpload.getFiles().getFile(0).getFileName();\tString maskname = ""+System.currentTimeMillis();\tint    filesize = myUpload.getFiles().getFile(0).getSize();\tint    count=0;\ttry {\t\tcount = myUpload.save(savePath);// Rename file\t\tFile up1 = new File(savePath+filename);\t\tFile up2 = new File(savePath+maskname);\t\tif (up1.exists()) {\t\t        boolean rslt = up1.renameTo(up2);\t\t}\t} catch (Exception e) {\t\tout.println(e.toString());\t}---------------------------------------------------제가 테스트를 해보았는데 파일이름이 바뀌질 않던데..어떻게 하신건가요?',
#   ()),
#  '#238': ('초보자',
#   '2001-08-02 10:19:46',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'Error 좀 봐 주세요.',
#   '개발환경은  win2000, apache, tomcat 입니다.무슨 에러인지? 어디를 살펴봐야 하는지요?Error: 500Location: /listDept.jspInternal Servlet Error:javax.servlet.ServletException: Fatal Error: missing resource: java.util.PropertyResourceBundle\tat org.apache.jasper.servlet.JspServlet.service(JspServlet.java:508)\tat javax.servlet.http.HttpServlet.service(HttpServlet.java:853)\tat org.apache.tomcat.core.ServletWrapper.doService(ServletWrapper.java:405)\tat org.apache.tomcat.core.Handler.service(Handler.java:287)\tat org.apache.tomcat.core.ServletWrapper.service(ServletWrapper.java:372)\tat org.apache.tomcat.core.ContextManager.internalService(ContextManager.java:812)\tat org.apache.tomcat.core.ContextManager.service(ContextManager.java:758)\tat org.apache.tomcat.service.connector.Ajp12ConnectionHandler.processConnection(Ajp12ConnectionHandler.java:166)\tat org.apache.tomcat.service.TcpWorkerThread.runIt(PoolTcpEndpoint.java:416)\tat org.apache.tomcat.util.ThreadPool$ControlRunnable.run(ThreadPool.java:501)\tat java.lang.Thread.run(Thread.java:484)Root cause:java.lang.Error: Fatal Error: missing resource: java.util.PropertyResourceBundle\tat org.apache.jasper.Constants.getString(Constants.java:213)\tat org.apache.jasper.Constants.getString(Constants.java:196)\tat org.apache.jasper.compiler.SetPropertyGenerator.generate(SetPropertyGenerator.java:101)\tat org.apache.jasper.compiler.JspParseEventListener$GeneratorWrapper.generate(JspParseEventListener.java:771)\tat org.apache.jasper.compiler.JspParseEventListener.generateAll(JspParseEventListener.java:220)\tat org.apache.jasper.compiler.JspParseEventListener.endPageProcessing(JspParseEventListener.java:175)\tat org.apache.jasper.compiler.Compiler.compile(Compiler.java:210)\tat org.apache.jasper.servlet.JspServlet.doLoadJSP(JspServlet.java:612)\tat org.apache.jasper.servlet.JasperLoader12.loadJSP(JasperLoader12.java:146)\tat org.apache.jasper.servlet.JspServlet.loadJSP(JspServlet.java:542)\tat org.apache.jasper.servlet.JspServlet$JspServletWrapper.loadIfNecessary(JspServlet.java:258)\tat org.apache.jasper.servlet.JspServlet$JspServletWrapper.service(JspServlet.java:268)\tat org.apache.jasper.servlet.JspServlet.serviceJspFile(JspServlet.java:429)\tat org.apache.jasper.servlet.JspServlet.service(JspServlet.java:500)\tat javax.servlet.http.HttpServlet.service(HttpServlet.java:853)\tat org.apache.tomcat.core.ServletWrapper.doService(ServletWrapper.java:405)\tat org.apache.tomcat.core.Handler.service(Handler.java:287)\tat org.apache.tomcat.core.ServletWrapper.service(ServletWrapper.java:372)\tat org.apache.tomcat.core.ContextManager.internalService(ContextManager.java:812)\tat org.apache.tomcat.core.ContextManager.service(ContextManager.java:758)\tat org.apache.tomcat.service.connector.Ajp12ConnectionHandler.processConnection(Ajp12ConnectionHandler.java:166)\tat org.apache.tomcat.service.TcpWorkerThread.runIt(PoolTcpEndpoint.java:416)\tat org.apache.tomcat.util.ThreadPool$ControlRunnable.run(ThreadPool.java:501)\tat java.lang.Thread.run(Thread.java:484)',
#   ()),
#  '#239': ('김종환',
#   '2001-08-02 10:34:46',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '질문이 있는데요...',
#   '지금 WebDox에서 나온 바이블을 보고 있는데요.그쪽 사이트에서는 답변이 없어서 이렇게 질문을 합니다.어떤 내용이냐면 처음에 데이터베이스에 분류를 넣어둡니다.그리고 빈에서 가져와서 jsp문서에서 분류를 출력을 하는 건데요. 이때 가져오는 것까지는 한글로 가져와집니다. 그러니깐System.out.println("분류:"+c.getName());이렇게 하면 서버에 출력이 되잖아요. 이때는 분명히 한글인데이걸 jsp문서에서 <%=c.getName()%>으로 출력을 하면 한글이깨져서 나옵니다. 이게 왜이런지 모르겠네요.혹시 똑같은 경험을 하신분이 있으시거나 왜 이런지 아시는분은좀 가르쳐주시기 바랍니다.',
#   ()),
#  '#248': ('최인선',
#   '2001-08-02 11:45:26',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '여기올라와있는 소스중에 FileUpload중에',
#   'import javax.servlet.*;import javax.servlet.http.*;이부분에서  not exist라는 에러가 납니다.javax.servlet를 쓰려면 웹서버가 필요하다는 얘기가 있는데전 win2000pro에 tomcat+apache를 돌리구 있거든요그래서 잘 안되네요senFile.java 컴파일 잘되신분 답좀 올려주세요',
#   ()),
#  '#249': ('simbamir',
#   '2001-08-02 12:27:52',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '방명록의 페이징 기법에러..................',
#   '제가 만든 방명록의 페이징기법을 사용했는데.잘 안되거든요..제가 bean파일과 list.jsp파일을 첨부파일로올립니다.함 바주세요..저는 resin2.0과 mysql을 사용했습니다..그럼 더운데 수거하세요..',
#   ()),
#  '#255': ('김종환',
#   '2001-08-02 14:55:08',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '또 질문이 있어서요...^^;;',
# ...
#   ' 0',
#   '0',
#   'To와 Bcc의 차이점..',
#   '안녕하세요...자바메일을 공부하구 있는데요..받는사람을 To로 보내는것과 Bcc로 보내는것에 있어서속도상의 차이가 있나요?',
#   ()),
#  '#30': ('현정희',
#   '2001-07-26 17:21:59',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '절대경로는....',
#   'function view(temp) { if (temp.length >0) {//  url = "images/"+temp;  url= "http://localhost/examples/shop/images/"+temp;  window.open(url, "win",     "height=550,width=550,toolbar=0,menubar=0,scrollbars=1,resizable=1,status=0"); }}url= "http://localhost/examples/shop/images/"+temp;를 절대경로를 설정해줄수는 없나요. 그러니깐 shop/images/에 있기는 있는데............문제는 다른 사람의 컴퓨터에 심을 때 소스를 수정하지 않고 사용하는 방법이요....그럴수 없나요...',
#   ()),
#  '#31': ('푸쉬카르',
#   '2001-07-26 17:26:29',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '답변하면서 메일 보내기...',
#   'Q&A old 에서는 답변과 동시에 그 사람에게로 메일이 가잖아요... 그렇게 하려면.. 강좌에 있는 javamail 부분을 보면 되는 건가요.. 알려주세요.. 혹시 소스 있으시면.. 더 좋구요..또 한가지.. 새로 올라온 글 옆에 new라는 표시요.. 그렇게 해주려면.. 어찌해야 하나요.. 참고 소스 좀 알려주세요..그럼.. 수고하시고요.. 새로운 Q&A open 축하드립니다..',
#   ()),
#  '#32': ('갱수',
#   '2001-07-26 17:37:31',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '쿠키가 한번만 삭제되요..',
#   '특정 쿠키를 지우고자 아래와 같이 했답니다..Cookie dcookie = new Cookie(cookiename, "");dcookie.setMaxAge(0);res.addCookie(dcookie);근데 처음 한번만 지워지고 다시 생성후 다시 지우면 지워지지 않습니다어떻게 된 일일까요?....참고로 쿠키삭제 모듈은 JSP BEAN 모듈안에 있습니다뭐가 잘못되었는지 고수님들의 충고 부탁드립니다.',
#   ()),
#  '#35': ('김성진',
#   '2001-07-26 21:14:41',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '[질문] jk_nt_service에 대해서',
#   '님의 강좌에 있는 nt에서 서비스 설정하는 법을 따라 해봤는데.. 잘 되질 않네여...서비스에 등록은 되는데 서비스 시작은 안되더라구여..그래서 도스프롬프트창에서 jk_nt_service jakarta 해서 보니 여전히 에러...이벤트 로그를 보니 다음과 같은 에러가 있더라구여..                - 에러 내용-이벤트 ID( 0 )(원본 ( Jakrta - Tomcat )에 있음)에 대한 설명을 찾을 수 없습니다. 로컬 컴퓨터에 원격 컴퓨터에서 보낸 메시지를 표시하기 위해 필요한 레지스트리 정보 또는 메시지 DLL 파일이 없을 수 있습니다. 다음 정보는 이벤트의 일부입니다. Jakrta - Tomcat error: 1063, StartServiceCtrlDispatcher failed..이건 왜 이런걸까여..?문제 해결 방안좀...',
#   ()),
#  '#44': ('현아~',
#   '2001-07-27 01:49:06',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '와~',
#   '안녕하세요~~몇일 못들어왔는데 이렇게 바꼈네요..kenu님.. 정말 부러워요...나두 이렇게 될수 있을까?? T_T저 질문있어서요..자바메일하는데요.. 한글문제가 생겨서요..음... 모든 웹메일과 outlook에두 잘 가는데..이융~~ 상업용 메일 관리 프로그램에서 제목이 깨져서 가네요..setSubject()를 사용해보구.. 다른 모든 한글관련 인코딩을 해봤는데.. 안돼네요..참!! 그리고..setSubject()는 api에서 보니까..setSubject(스트링, 스트링charset)을 사용할수 있게되어있던데..   setSubject("메거진", "EUC-KR");이렇게 적용이 안돼네요...제가 받은 다른 웹메일을 보내보니..안깨지구 잘 나오던데..에궁~~~ 잘 안돼네요..그럼.. 답변 부탁드릴께요...',
#   ()),
#  '#45': ('김학성',
#   '2001-07-27 02:24:57',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '파일생성시 궁금합니다.',
#   '파일생성시<%@ page import="java.sql.*"%><%@ page language="java" contentType="application/vnd.ms-excel; name=\'My_Excel\';charset=euc-kr" %><%response.setHeader("Content-Disposition", "inline; filename=myfile.xls");response.setHeader("Content-Description", "JSP Generated Data");%>위에서 처럼만 정의하면 되는데 이 파일을 저장해서 클라이언트에서도 생성해서 사용을 해야합니다.질문 1 : php에서는 fopen()함수등으로 저장장소를 지정도 가능한데 jsp에서는 어디에 저장이 되는지 모르겠구요, 왜냐면 파일생성시 계속 덮어씌우며 저장이 되어야 하기때문에...질문 2 : 엑셀파일 생성시 레코드는 1개가 아니라 3개씩(한줄에) 출력이 가능한지?알고 싶습니다.고수님들 한수 가르쳐주세요.',
#   ()),
#  '#48': ('김정태',
#   '2001-07-27 10:11:32',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '자바메일 보내는 사람 한글 표기',
#   "안녕하세요? 새 게시판이 보기 좋군요.. ^^다름이 아니라 자바메일을 이용해서 메일전송프로그램을하나 만들었는데요..한글 처리를 했는데도 보내는 사람 이름이 깨져 나옵니다.김정태<tornlips@hanmail.net> 이렇게 from을 설정해서스트링토크나이저로 쪼갠 담에 보내면 한글로 된 '김정태'부분이 깨져 배달되네요..사용환경은 아파치 + 톰캣 + SMTP(JAMES) 입니다...제가 궁금한 것은 다음 두가지입니다.1. 자바메일에서 위와 같이 보내는 사람과 보내는 사람 이메일을 분리해서 보낼 때 원래 보내는 사람 이름 한글처리가 안되는지??2. 되는 것이라면 일반적인 한글 처리이외에 다른 방법이있는지?바쁘시더라도 답변 부탁드리겠습니다.수고하세요.. ^^",
#   ()),
#  '#52': ('kenu',
#   '2001-07-27 11:11:05',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '[공지]글이 안 올라가시는 분',
#   '혹시 계시다면kenu@okjsp.pe.kr로 제목과 내용을 보내주세요.첨부파일도 같이 보내주세요.',
#   ()),
#  '#53': ('박선형',
#   '2001-07-27 11:45:45',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '에러 500 이 나는데',
#   '안녕하세요?저는 막 JSP시작한 초보입니다.현재 설치 문제로 3일간 고생하고 있는데요.win2000 Professional 에 tomcat3.2.3 을 깔았고여기 강좌대로 다 했는데http:\\\\localhost:8080\\을 하면Error: 500Location: /Internal Servlet Error:java.io.IOException: Not an ISO 8859_1 character:수이런 에러가 뜹니다. 어떻해 해야 하는지요?알려주세요^^',
#   ()),
#  '#56': ('서경수',
#   '2001-07-27 12:10:26',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'introspect와 reflection은 어떻게 구분될 수 있을까요 ?',
#   'introspect와 reflection은 어떻게 구분될 수 있을까요 ?',
#   ()),
#  '#58': ('처버^^a',
#   '2001-07-27 12:40:36',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '누가 이 문제 좀 해결해주세요...ㅜㅠ  벌써 1주일이 넘었어요...',
#   '환경은 win2000Server + resin(이것저것 다 해서... 버젼이 뭐라 할 수가 없네요...^^;) + jdk1.3.1입니다.url에 80포트를 사용하여 직접 입력하여 jsp를 호출합니다.  여기까지는 잘 되지만, 문제는 그 페이지에서 submit을 보낼때 페이지를 찾을 수 없다는 메세지가 나옵니다.ㅡㅡ"  게다가 신기한 것은 8080포트를 사용하거나, get방식을 이용하면 전혀 이상이 없이 페이지가 넘어갑니다.십수번을 깔고 수정하고, 지우기도 해봤지만, 도무지가 해결이 안됩니다.  제발 이 문제를 해결해주실분이 나타나시길 기도합니다.....그리고 여기 운영자님에게는 계속 같은 질문만 올려서 죄송하네요...^^;',
#   ()),
#  '#60': ('김재철',
#   '2001-07-27 15:30:51',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'win2k+IIS+tomcat에서 tomcat실행이 안되는데여...',
#   '님 강좌를 넘넘 고맙게 보구 있는 회사원입니다...님 강좌중에 위의 사양을 조정하는게 있는데...제가 잘 몰라서... 여기저기 짬뽕하려니깐 힘들군여...JDK1.3 Path 거는거부터 시작해서 자세히 설명해주시면 안되나여???JSP를 돌리려구 하는데 아무것두 안되니깐... 답답하네여...제발 해결좀 해주세여...',
#   ()),
#  '#61': ('윤지석',
#   '2001-07-27 15:39:45',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'iis 와 톰켓 3.2.3 연동',
#   '안녕하세여..어제 세팅을 마무릴 하고 iis와 톰켓이 연동되는걸 확인했어여그런데 오늘 확인해보니 충돌이 일어났는지 메일서버(exchange)가 죽었더라구여... 다시 살려는 났지만언제 또 충돌이 일어나서 한쪽이 죽을지 걱정되는군여.ㅡ.ㅜ일단 메일이 중요하기 때문에 톰켓을 죽여났습니다..왜그러는지 ㅡ.ㅜ정말 서버셋팅 넘 어렵네여... 공부할게 갑자기 산더미가 된거같네여..kenu님 답변주심 또한번 감사합니다..아참 제가 환경설정하는도중에** conf 에 있는 uriworkermap.properties 파일을 열어서 한줄을 추가합니다. /*.jsp=ajp12 를 적어주면 Root 디렉토리에 있는 jsp 파일을 iis가 아닌 Tomcat으로 처리하게 됩니다. 다른 컨텍스트도 /examples/ 설정과 같은 방식으로 해주면 됩니다. **--> 여기선 저는 마지막줄만 추가 했는데    (다른 컨텍스트도 /examples/ 설정과 같은 방식으로 해주면 됩니다) 이말은 또 설정할게 있다는말인가여??** wrapper.class path=d:\\oracle\\ora81\\jdbc\\lib\\classes12.zip==>서비스 설치하기에서 전 이 설정을 하지 않았습니다...혹시 db연동때문에 문제가 있는걸가여?? (제 환경은 nt4.0, MS-SQL 7.0 입니다)',
#   ()),
#  '#63': ('정민',
#   '2001-07-27 15:53:37',
#   ('java', ' jsp'),
#   ' 1',
#   '0',
#   '마셜링이라 ... 이게 뭐지요 ?',
#   'rmi에 나오는 데 설명이 없어서요 ?',
#   ()),
#  '#65': ('지나가는과객',
#   '2001-07-27 17:40:22',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '자바메일 클래스낫화운드.. 살려주십시요,',
#   '/mail.jsp:14: package javax.mail does not existimport javax.mail.*;^/mail.jsp:15: package javax.mail.internet does not existimport javax.mail.internet.*;클래스 패스두 확인해서 적어주었고 확인을 계속해봐두 여전히 저를괴롭히는문구이군요. 미티미티.. 왜이럴까요..jdk1.3하궁 jaf1.0.1하궁 자바메일1.1.3인데..이놈의 클래스는 무슨 맨날..이모양이죠. 답변기다리겠읍니다.',
#   ()),
#  '#66': ('누기',
#   '2001-07-27 17:42:28',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'tomcat 3.2.3 실행이 안되요',
#   '우선 startup을 실행시키면 도스창에서 이런 메세지가 뜹니다."You must set JAVA_HOME to point at your Java Development Kit installation"이건 제 패스 내용이고요PATH C:\\ORAWIN95\\BIN;C:\\jdk1.3.1\\bin;C:\\jdk1.3.1\\libSET JAVA_HOME =C:\\jdk1.3.1SET TOMCAT_HOME = C:\\jakarta-tomcatSET CLASSPATH =.;%CLASSPATH%;C:\\jdk1.3.1\\lib\\tools.jarstartup에 대한 메모리도 4096으로 만들어 주고 했는데...글구 jdk도 다 깔았는데 왜 이러지요?참고로 win98입니다.',
#   ()),
#  '#68': ('박현호',
#   '2001-07-27 20:41:04',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'transport.send(msg)라는 부분에서 exception이 일어납니다',
#   '소스를 보시고왜 이 곳에서 error가 나는지 좀가르쳐 주세요도움을 바랍니다------------------------------------------------------------try {        // Session을 생성하기 위해 java.util.Properties 클래스를        // 생성하고 SMTP 호스트 주소를 할당합니다.        Properties props = new Properties();        props.put("mail.smtp.host", "localhost");        // 기본 Session을 생성하고 할당합니다.        Session msgSession = Session.getDefaultInstance(props, null);        msgSession.setDebug(debug);        // Message 클래스의 객체를 Session을 이용해 생성합니다.        MimeMessage msg = new MimeMessage(msgSession);        // From, subject, content를 설정합니다.        InternetAddress addrFrom = new InternetAddress("dudus25@hanmail.net");        msg.setFrom(addrFrom);        msg.setSubject(subject);        msg.setText(content, "euc-kr");        // 데이터베이스의 주소부분을 가져와 TO를 설정합니다.        while(rs.next()) {            InternetAddress addrTo = new InternetAddress(rs.getString("email"));            msg.setRecipient(Message.RecipientType.TO, addrTo);===========================================바로 요 부분에서  exception 이 일어납니다STMP 의 relation 허가를 localhost로 했는데도요것이 말을 않듣네요            // 메일을 발송합니다.            Transport.send(msg);        }',
#   ()),
#  '#70': ('이정석',
#   '2001-07-28 00:23:05',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '질문이요...',
#   'jsp강좌 두번째에서 아래부분이 안되는 군요."이전과 다르게 8080을 빼고, http://localhost/examples/jsp 를 쳐서 jsp쪽으로 가는지 확인합니다"페이지를 찾을 수 없다고 나오는데 어디서 잘못됐는지 모르겠네요. 가르쳐주세요...',
#   ()),
#  '#8': ('kenu',
#   '2001-07-26 04:20:45',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '게시판 이동했습니다.',
#   'okboard 0.9버전입니다.이전 게시판처럼 메일이 가지는 않습니다.환경이 ... ^^;어쨌든 옆에 소스게시판에서 업그레이드가 되는대로 반영이 될 것입니다.',
#   ()),
#  '#87': ('이정석',
#   '2001-07-28 02:58:09',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '질문이여....',
#   '정말 매번 정성히 답변해 주셔서 너무 고맙습니다. 근데잠두 안 주무시고 어찌게 그렇게 빨리 답변해 주세요?-^^-그런데요 아파치,톰켓 설치한 컴퓨터에서 밖에 jsp를 실행할 수 없나요? 원격에서도 가능할 것 같은데...혹시아시나요?',
#   ()),
#  '#88': ('한재택',
#   '2001-07-28 03:05:02',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '아파치와 톰캣을 설치시 에러..',
#   '2001-07-28 02:52:17 - ContextManager: Adding context Ctx( /examples )2001-07-28 02:52:17 - ContextManager: Adding context Ctx( /admin )Starting tomcat. Check logs/tomcat.log for error messages2001-07-28 02:52:17 - ContextManager: Adding context Ctx(  )2001-07-28 02:52:17 - ContextManager: Adding context Ctx( /test )2001-07-28 02:52:18 - PoolTcpConnector: Starting HttpConnectionHandler on 802001-07-28 02:52:18 - PoolTcpConnector: Starting Ajp12ConnectionHandler on 8007위와 같은 에러메시지가 뜨는데 무엇이 잘못된건지 좀 가르쳐주세요....',
#   ()),
#  '#9': ('kenu',
#   '2001-07-26 05:15:56',
#   ('java', ' jsp'),
#   ' 1',
#   '0',
#   '이 게시판 소스입니다.',
#   '/*   okboard 0.9   작성자 : kenu@okjsp.pe.kr   배포처 : http://www.okjsp.pe.kr   작성일 : 2001-07-26 5:04오전   테스트 : http://okjsp.pe.kr/ Q&A 게시판*/Oracle8i, jspSmartUpload 를 이용한 자료게시판입니다.현재개발환경IIS5tomcat 4.0 beta5, tomcat 3.2.3Oracle 8.1.6,8.1.7설치법root(예: c:/jsphome)c:/jsphome/index.htmlc:/jsphome/okboard/admin.jsp         <-- 게시판 관리자 인증처리c:/jsphome/okboard/top.jsp           <-- 페이지 상단 처리c:/jsphome/okboard/bottom.jsp        <-- 게시판 하단 처리c:/jsphome/okboard/boardcfg.jsp      <-- 게시판 테이블명 환경설정/ 관리자 비밀번호c:/jsphome/okboard/board_create.jsp  <-- 게시판 생성 한번실행 후 파일명 바꾸시거나 삭제하세요.c:/jsphome/okboard/board_delete.jsp  <-- 게시판 drop 시킵니다 파일명 바꾸시거나 삭제하세요.c:/jsphome/okboard/board.jsp         <-- 게시물리스트c:/jsphome/okboard/board_insert.jsp  <-- 자료 입력폼c:/jsphome/okboard/board_insert2.jsp <-- 자료 입력처리c:/jsphome/okboard/board_reply.jsp   <-- 답변 입력폼c:/jsphome/okboard/board_reply2.jsp  <-- 답변 입력처리c:/jsphome/okboard/passchk.jsp       <-- 수정권한 암호 입력c:/jsphome/okboard/board_modify.jsp  <-- 수정폼c:/jsphome/okboard/board_modify2.jsp <-- 수정처리c:/jsphome/okboard/db.jsp            <-- jdbc 정보파일c:/jsphome/okboard/go.jsp            <-- back 방지용 중계처리c:/jsphome/okboard/delete.jsp        <-- 삭제권한 암호 입력c:/jsphome/okboard/delete2.jsp       <-- 삭제처리c:/jsphome/okboard/path.jsp          <-- jvm의 classpath 확인c:/jsphome/okboard/download.jsp      <-- 다운로드 처리c:/jsphome/okboard/okboard.css       <-- 페이지 CSSc:/jsphome/okboard/okboard.js        <-- javascriptc:/jsphome/okboard/images/           <-- 그림파일 디렉토리c:/jsphome/WEB-INF/classes/com/      <-- JspSmartUpload 컴포넌트 디렉토리c:/jsphome/WEB-INF/classes/ok/       <-- 한글처리, 문자열대치, 쿠키처리 빈c:/jsphome/upload/                   <-- 파일이 업로드되는 디렉토리※ D:\\oracle\\ora81\\jdbc\\lib\\classes12.zip 이 jvm 의 classpath 에 인식이 되어야 합니다.   그렇지 않을 경우 java.lang.ClassNotFoundException: oracle.jdbc.driver.OracleDriver 메세지가 뜹니다.   Oracle 8.0 이하는 쿼리가 제대로 동작하지 않을 수 있습니다.실행법설치 완료 후 tomcat을 구동시킨 후브라우저에서 http://localhost/okboard/board_create.jsp 를 요청합니다.kboard 라는 table 이 만들어 지면 됩니다.board_create.jsp 파일 이름을 바꿔주세요.board_delete.jsp 파일 이름을 바꿔주세요. 테이블리셋 시에 바꾼이름을 브라우저에서 요청하면 됩니다.보안oracle의 데이터베이스의 기본 접근권한으로 되어있습니다. (scott, tiger)변경을 원하시면 db.jsp 파일만 수정하시면 됩니다.게시판관리자 패스워드 변경은 boardcfg.jsp 파일에서 하실 수 있습니다.table 구성 (kboard, kboard_cnts)CREATE TABLE KBOARD ( BBSID VARCHAR2 (10) NOT NULL, SEQ NUMBER NOT NULL, REF NUMBER NOT NULL, STEP NUMBER DEFAULT 0 NOT NULL, LEV NUMBER DEFAULT 0 NOT NULL, WRITER VARCHAR2 (50) NOT NULL, SUBJECT VARCHAR2 (500) NOT NULL, PASSWORD VARCHAR2 (8), EMAIL VARCHAR2 (50), READ NUMBER DEFAULT 0 NOT NULL, FILENAME VARCHAR2 (200), MASKNAME VARCHAR2 (20), FILESIZE NUMBER DEFAULT 0, DOWNLOAD NUMBER DEFAULT 0, WHEN DATE, IP VARCHAR2 (24)) ;CREATE TABLE KBOARD_CNTS ( BBSID VARCHAR2 (10) NOT NULL, SEQ NUMBER NOT NULL, CONTENT VARCHAR2 (4000), CID NUMBER DEFAULT 0 NOT NULL) ;0.82- 2001-07-26 4:51오전관리자 삭제 기능 추가 - 인증만 거치면 삭제시 패스워드 불문 (session 사용)top.jsp 와 bottom.jsp 를 통한 다중게시판 커스터마이징 가능okboard.css 의 ok-1 스타일을 통해 타이틀 배경색 지정가능페이지 링크에서 파라메터 최적화게시판 html 코드 보이기0.81- 2001-07-24 2:14오전내용 검색 버그 수정0.8- 2001-07-13 6:19오전DB Schema 에 SEQ (일련번호) 추가 및 효율화한글 검색 페이지 넘어가면 안되는 버그 수정list 에서 tag 장난방지당일 게시물은 시간으로 목록에 표시3일 이내 게시물 구분표시페이지그룹 이동 시 다음페이지의 처음과 끝 게시물로 이동download 시 스트림 확실히 끊어주기글쓰기, 수정, 답변 시 취소버튼 추가main.jsp, Article.java, ArticleLists.java - bean test 파일, bug 많음0.7- 2001-05-28 2:28오전게시물 보기에서 관련글 리스트 출력게시물 보기에서 이전, 다음글 링크 추가DB Connection 중 사용한 Statement 랑 PreparedStatement 끊어주기게시물 목록에서 제목길이 30자 제한리스트에서 현재 페이지 굵게 표시0.62 -  2001-05-24 11:26오후검색후 리스트 버그 수정최근 3일 게시물 표시Timestamp와 SimpleDataFormat을 이용한 날짜표시0.61 -  2001-05-23 6:33오전리스트 버그 수정0.6 -  2001-05-21 1:58오전게시판 제목, 이름, 내용 검색 추가select 항목 지정하는 javascript 추가0.5 -  2001-05-20 1:11오전수정기능 추가Cookie로 입력신상 저장0.4 -  2001-05-18 10:56오전답변기능 추가Fn.java 버그 수정0.3 -  2001-05-17 5:57오후오라클의 4000바이트 제한을 풀었습니다.다운로드 방식을 바꾸었습니다.한글제목파일, 이미지 다운로드시 이상없습니다.게시물 작성 후 refresh 되도록 했습니다.email 링크로 변경했습니다.doc, xls, ppt, gif, img 모두 다운로드 창 뜹니다.jsp 코드 올려도 실행되지 않습니다.전신kboard 를 오라클용으로 전환합니다.',
#   ()),
#  '#91': ('한재택',
#   '2001-07-28 03:41:00',
#   ('java', ' jsp'),
#   ' 3',
#   '0',
#   '초보적인 질문요...^.^;',
#   'jsp를 좀하려고하니 처음부터 참힘드네요...지금 톰캣하고 아파치를 설치를 했는데 잘되는 건지 잘모르겟어요..그리고 톰캣만 실행시켜도 jsp는 돌아가지 안나요?구지 아파치를 설치하는 이유가뭔가요?글구요 아래메시지중 log에러가 나는 이유는 무엇인지요?마지막으로2001-07-28 03:23:39 - ContextManager: Adding context Ctx( /examples )2001-07-28 03:23:39 - ContextManager: Adding context Ctx( /admin )Starting tomcat. Check logs/tomcat.log for error messages2001-07-28 03:23:39 - ContextManager: Adding context Ctx(  )2001-07-28 03:23:39 - ContextManager: Adding context Ctx( /test )2001-07-28 03:23:43 - PoolTcpConnector: Starting HttpConnectionHandler on 802001-07-28 03:23:43 - PoolTcpConnector: Starting Ajp12ConnectionHandler on 80072001-07-28 03:24:38 - Ctx( /examples ): JasperException: R( /examples + /jsp/num/numguess.jsp + null) Unable to rename class file C:\\jakarta-tomcat\\work\\localhost_8080%2Fexamples\\jsp\\num\\_0002fjsp_0002fnum_0002fnumguess_0002ejspnumguess_jsp_0.class to C:\\jakarta-tomcat\\work\\localhost_8080%2Fexamples\\_0002fjsp_0002fnum_0002fnumguess_0002ejspnumguess.class2001-07-28 03:24:49 - Ctx( /examples ): IOException in: R( /examples + /jsp/num/numguess.jsp + null) Connection reset by peer: socket write error2001-07-28 03:24:49 - Ctx( /examples ): IOException in: R( /examples + /jsp/num/numguess.jsp + null) Connection reset by peer: socket write error이런 메시지가 뜨는데 이상이 없는건가요?',
#   ()),
#  '#92': ('자바초보',
#   '2001-07-28 04:04:33',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '운영자님 질문^^;;',
#   '이거참 그냥 간단한 선그리는 건데,,이거 프레임에서안뜨니,,정말 답답합니다,가르쳐주세여import java.awt.*;import java.awt.event.*;public class DrawLine extends Frame{   DrawArea area;   public DrawLine()   {       setLayout(new BorderLayout());       addWindowListener(new WinListener());\t   area = new DrawArea();\t   add(area,BorderLayout.CENTER);\t   }\t   class DrawArea extends Canvas\t   {\t       public void paint(Graphics g){\t\t  int x1;                   int y5;\t\t  int x3;\t\t  int y7;\t\t\t  g.drawLine(0,5,3,7);\t   }\t   }\t   public static void main(String args[])\t   {\t       DrawLine T = new DrawLine();\t\t    T.setSize(500,300);\t\t\tT.show();\t\t\t}\t\t\tclass WinListener extends WindowAdapter\t\t\t{\t\t\t   public void windowClosing(WindowEvent we)\t\t\t   {\t\t\t     System.exit(0);                       }\t\t\t}\t\t\t}',
#   ()),
#  '#97': ('윤지석',
#   '2001-07-28 12:53:53',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   'kenu 님~~',
#   '항상 님의 답변 감사드립니다..혼자 해결해야하는 저의 입장으로서 큰 힘이 되네여..무더운 여름 건강히 잘 보내시구여^^',
#   ()),
#  '#98': ('현정희',
#   '2001-07-28 13:28:47',
#   ('java', ' jsp'),
#   ' 0',
#   '0',
#   '검색하기기능에서요...',
#   '안녕하세요.검색하기 기능을 구현하고 있는데 검색이 안돼는군요.그래서 님의 보드0.5(mysql)을 제 컴에 심었는데, 검색 기능이 구현이 안됩니다.좀 가르쳐주세요. 전 검색한걸 페이지 나누는게 더 힘들줄 알았는데, 검색이 안돼니.....',
#   ())}

# %%
with open('answers.dic','rb') as fp:
    answers = pickle.load(fp)
answers
# Out:
# {'#1': {'#1_0': ('j a e g e r',
#    '2012-08-23 14:45:04',
#    '1',
#    'http://www.okjsp.pe.kr/seq/1seq 1번 게시물 ㄷㄷㄷ')},
#  '#10': {},
#  '#103': {},
#  '#104': {},
#  '#107': {},
#  '#108': {},
#  '#109': {},
#  '#113': {},
#  '#117': {},
#  '#119': {},
#  '#120': {},
#  '#125': {},
#  '#126': {},
#  '#128': {},
#  '#129': {},
#  '#130': {},
#  '#131': {},
#  '#132': {},
#  '#133': {'#133_0': ('재용',
#    '2003-11-12 18:03:33',
#    '0',
#    'String arr[] = x.split("$");'),
#   '#133_1': ('세브니',
#    '2003-11-12 18:21:11',
#    '0',
#    'String[] arr vs. String arr[]어떤 차이가 있을까요?'),
#   '#133_2': ('세브니', '2003-11-12 19:55:44', '0', 'java style vs. c style')},
#  '#134': {},
#  '#136': {},
#  '#14': {},
#  '#141': {},
#  '#142': {},
#  '#143': {},
#  '#145': {},
#  '#153': {},
#  '#157': {},
#  '#161': {},
#  '#162': {},
#  '#163': {},
#  '#166': {},
#  '#170': {},
#  '#174': {},
#  '#176': {},
#  '#177': {},
#  '#179': {},
#  '#185': {},
#  '#186': {},
#  '#188': {},
#  '#189': {},
#  '#2': {},
#  '#205': {},
#  '#206': {},
#  '#207': {},
#  '#208': {},
#  '#209': {'#209_0': ('후니', '2008-01-17 14:44:36', '0', '머지 이거')},
#  '#210': {},
#  '#215': {},
#  '#218': {},
#  '#220': {},
#  '#223': {},
#  '#227': {},
#  '#229': {},
#  '#23': {},
#  '#230': {},
#  '#232': {},
#  '#234': {},
#  '#238': {},
#  '#239': {},
#  '#248': {},
#  '#249': {},
#  '#255': {},
#  '#256': {},
#  '#257': {},
#  '#258': {},
#  '#259': {},
#  '#261': {},
#  '#262': {},
#  '#267': {},
#  '#269': {},
#  '#270': {},
#  '#271': {},
#  '#272': {},
#  '#30': {},
#  '#31': {},
#  '#32': {},
#  '#35': {},
#  '#44': {},
#  '#45': {},
#  '#48': {},
#  '#52': {},
#  '#53': {},
#  '#56': {},
#  '#58': {},
#  '#60': {},
#  '#61': {},
#  '#63': {'#63_0': ('BBK',
#    '2017-07-17 19:08:55',
#    '0',
#    '안녕하세요블루비콘코리아 채용담당자 입니다.위에 직무 정보는 예를 들어 기재 한 것이니 내용 참고 부탁드립니다.개발자 분들의 많은 지원 부탁드립니다.감사합니다.')},
#  '#65': {},
#  '#66': {},
#  '#68': {},
#  '#70': {},
#  '#8': {},
#  '#87': {},
#  '#88': {},
#  '#9': {'#9_0': ('asdf', '2008-01-25 20:12:08', '0', 'asdfasdf')},
#  '#91': {'#91_0': ('itwbyoc ajxkntu',
#    '2007-06-06 12:55:23',
#    '0',
#    'enlvrdo nabolvc vgzx hxbun sgtwcfpn cfgjm nsbt'),
#   '#91_1': ('xanriqwl lbmuahxry',
#    '2007-06-06 12:55:57',
#    '0',
#    'zrvyshla ohvd mktnyox qdtebvizw dcol nlwheptg hjzs http://www.oikedgns.edbuj.com'),
#   '#91_2': ('xanriqwl lbmuahxry',
#    '2007-06-06 12:56:35',
#    '0',
#    'zrvyshla ohvd mktnyox qdtebvizw dcol nlwheptg hjzs http://www.oikedgns.edbuj.com')},
#  '#92': {},
#  '#97': {},
#  '#98': {}}
